# %%
import pandas as pd
import numpy as np
import seaborn as sns

from datetime import datetime
from dateutil.relativedelta import relativedelta
from suntimes import SunTimes

# %%
skip = 1
numsteps = int(163 // skip)
ds_inputs_DE1 = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\saved_ML_datasets\\DE_ML_ERA5_2001_2024_full.csv')
ds_inputs_DE1[[f't2max at day {skip*n}' for n in range(180)]] += -273.15
ds_inputs_DE1[[f't2min at day {skip*n}' for n in range(180)]] += -273.15
ds_inputs_DE2 = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\saved_ML_datasets\\DE_ML_ERA5_90s.csv')
ds_inputs_DE = pd.concat([ds_inputs_DE1, ds_inputs_DE2], axis = 0)
ds_fixed_vpd = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\Maize_ML_data_ERA5_fixed_vpd.csv')
ds_inputs_DE = ds_inputs_DE.drop(columns = [f'vpd at day {skip*n}' for n in range(180)])
ds_inputs_DE = pd.merge(ds_inputs_DE, ds_fixed_vpd[['Stations_id', 'Referenzjahr'] + [f'vpd at day {n}' for n in range(180)]], how = 'inner', on = ['Stations_id', 'Referenzjahr'])
ds_inputs_DE = ds_inputs_DE.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'])
ds_inputs_DE.to_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\saved_ML_datasets\\DE_ML_ERA5_full.csv')

# %%
identifying_columns = ['identifier', 'Stations_id', 'lat', 'lon', 'Management', 'vargroup', 'Referenzjahr']

# %%
ds_list = []
for variable_name in ['t2m', 't2min', 't2max', 'vpd', 'tp', 'ssrd']:
    #ds_SSA = pd.read_csv(f'C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\Maize_ML_data_SSA_{variable_name}_varieties2.csv').dropna(how='all')
    ds_SSA = pd.read_csv(f'C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\Maize_ML_data_SSA_{variable_name}_huge_set.csv').dropna(how='all')
    ds_SSA['observed time to beginning of flowering'] = pd.to_timedelta(ds_SSA['observed time to beginning of flowering']).dt.days#, 'D'
    ds_SSA = ds_SSA.loc[ds_SSA['observed time to beginning of flowering'] > 30] #30
    ds_list.append(ds_SSA)

# %%
numdays = 200
ds_full = ds_list[0]
for variable_ind, variable_name in enumerate(['t2min', 't2max', 'vpd', 'tp', 'ssrd']):
    print(variable_name)
    ds_full = ds_full.merge(ds_list[variable_ind + 1][identifying_columns + [f'{variable_name} at day {n}' for n in range (numdays)]], on = identifying_columns)
# Out:
# t2min
# t2max
# vpd
# tp
# ssrd

# %%
def get_categories(anthesis_date):
    return np.array([anthesis_date < n for n in range(200)]).squeeze().astype(np.int64)
cats = ds_full[['observed time to beginning of flowering']].apply(get_categories, args = (), axis = 1)
cats_unlisted = cats.apply(lambda x: pd.Series(x)) #to_frame().T#.explode()#.T.explode()
cats_unlisted = cats_unlisted.rename(columns = {n: f'dev stage at day {n}' for n in range(183)})
ds_full = ds_full.merge(cats_unlisted, left_index=True, right_index = True)

# %%
ds_full.loc[:, [f'DTF at day {n}' for n in range(193)]] = np.tile(ds_full['observed time to beginning of flowering'].values, (193, 1)).T - np.tile(np.arange(0, 193), (len(ds_full),1))
ds_full.loc[:, [f'dev stage at day {n}' for n in range(193)]] = (ds_full.loc[:, [f'DTF at day {n}' for n in range(193)]] < 0).astype(int).values

# %%
def get_photoperiods(inputs):
    #inputs = [lon, lat, day of start]
    day_of_start = datetime(inputs.iloc[2].year, inputs.iloc[2].month, inputs.iloc[2].day)
    lon = inputs.iloc[0]
    lat = inputs.iloc[1]
    sun = SunTimes(lon, lat) #can put altitude in also
    lengths = [(pd.to_datetime(sun.setutc(day_of_start + relativedelta(days=n))) - pd.to_datetime(sun.riseutc(day_of_start + relativedelta(days=n)))).seconds/3600 for n in range(170)]
    return np.array(lengths).squeeze().astype(np.float64)

# %%
def get_station_locations(dataset, ds_stations):
    ds_stations.index = ds_stations['LocationID']
    lat = [ds_stations._get_value(row, col) for row, col in zip(dataset['sitecode'], ['Latitude' for count in range(len(dataset))])] #station_data.lookup(row_labels = dataset['Stations_id'], col_labels = ['geograph.Breite'])
    lon = [ds_stations._get_value(row, col) for row, col in zip(dataset['sitecode'], ['Longitude' for count in range(len(dataset))])] #station_data._lookup(dataset['Stations_id'], ['geograph.Laenge'])
    dataset['lat'] = lat
    dataset['lon'] = lon
    dataset['lat'] = dataset['lat'].map(lambda x: x[0] if isinstance(x, float) == False else x)
    dataset['lon'] = dataset['lon'].map(lambda x: x[0] if isinstance(x, float) == False else x)
    return dataset

# %%
stations_data_lobell = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\African_data\\Lobell2011\\EIL_site_latlon.csv')
ds_full['sitecode'] = ds_full['Stations_id']
ds_full = get_station_locations(ds_full, stations_data_lobell)
# Out:
# C:\Users\wlwc1989\AppData\Local\Temp\ipykernel_16252\3268591058.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ds_full['sitecode'] = ds_full['Stations_id']

# %%
ds_full['Planting date'] = pd.to_datetime(ds_full['WC SOS date'])
photoperiods = ds_full[['lon', 'lat', 'Planting date']].drop_duplicates().apply(get_photoperiods, args = (), axis = 1)
# Out:
# C:\Users\wlwc1989\AppData\Local\Temp\ipykernel_16048\4280192466.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ds_full['Planting date'] = pd.to_datetime(ds_full['WC SOS date'])

# %%
photoperiods_unlisted = photoperiods.apply(lambda x: pd.Series(x)) #to_frame().T#.explode()#.T.explode()
photoperiods_unlisted = photoperiods_unlisted.rename(columns = {n: f'photoperiod at day {n}' for n in range(170)})
for vble in ['lat', 'lon', 'Planting date']:
    photoperiods_unlisted[vble] = ds_full[['lon', 'lat', 'Planting date']].drop_duplicates()[vble].values

# %%
ds_full = ds_full.merge(photoperiods_unlisted, how = 'left', on = ['lon', 'lat', 'Planting date'])

# %%
AEZ_data = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\African_data\\Lobell2011\\EIL_site_latlon_with_AEZ.csv')
AEZ_data = AEZ_data.rename(columns={'LocationID':'Stations_id'}).drop('Unnamed: 0', axis=1)

# %%
ds_full = ds_full.merge(AEZ_data[['Stations_id', 'AEZ']], on='Stations_id', how='left')

# %%
ds_full.to_csv(f'C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\saved_ML_datasets\\SSA_ML_ERA5_1999_2008_huge.csv')

# %%
ds_full = pd.read_csv(f'C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\saved_ML_datasets\\SSA_ML_ERA5_1999_2008_huge.csv')

# %%
ds_full.columns.to_list()
# Out:
# ['Unnamed: 0.1',
#  'Unnamed: 0',
#  'WC SOS date',
#  'Stations_id',
#  'lat',
#  'lon',
#  'Management',
#  'vargroup',
#  'Referenzjahr',
#  'identifier',
#  't2m at day 0',
#  't2m at day 1',
#  't2m at day 2',
#  't2m at day 3',
#  't2m at day 4',
#  't2m at day 5',
#  't2m at day 6',
#  't2m at day 7',
#  't2m at day 8',
#  't2m at day 9',
#  't2m at day 10',
#  't2m at day 11',
#  't2m at day 12',
#  't2m at day 13',
#  't2m at day 14',
#  't2m at day 15',
#  't2m at day 16',
#  't2m at day 17',
#  't2m at day 18',
#  't2m at day 19',
#  't2m at day 20',
#  't2m at day 21',
#  't2m at day 22',
#  't2m at day 23',
#  't2m at day 24',
#  't2m at day 25',
#  't2m at day 26',
#  't2m at day 27',
#  't2m at day 28',
#  't2m at day 29',
#  't2m at day 30',
#  't2m at day 31',
#  't2m at day 32',
#  't2m at day 33',
#  't2m at day 34',
#  't2m at day 35',
#  't2m at day 36',
#  't2m at day 37',
#  't2m at day 38',
#  't2m at day 39',
#  't2m at day 40',
#  't2m at day 41',
#  't2m at day 42',
#  't2m at day 43',
#  't2m at day 44',
#  't2m at day 45',
#  't2m at day 46',
#  't2m at day 47',
#  't2m at day 48',
#  't2m at day 49',
#  't2m at day 50',
#  't2m at day 51',
#  't2m at day 52',
#  't2m at day 53',
#  't2m at day 54',
#  't2m at day 55',
#  't2m at day 56',
#  't2m at day 57',
#  't2m at day 58',
#  't2m at day 59',
#  't2m at day 60',
#  't2m at day 61',
#  't2m at day 62',
#  't2m at day 63',
#  't2m at day 64',
#  't2m at day 65',
#  't2m at day 66',
#  't2m at day 67',
#  't2m at day 68',
#  't2m at day 69',
#  't2m at day 70',
#  't2m at day 71',
#  't2m at day 72',
#  't2m at day 73',
#  't2m at day 74',
#  't2m at day 75',
#  't2m at day 76',
#  't2m at day 77',
#  't2m at day 78',
#  't2m at day 79',
#  't2m at day 80',
#  't2m at day 81',
#  't2m at day 82',
#  't2m at day 83',
#  't2m at day 84',
#  't2m at day 85',
#  't2m at day 86',
#  't2m at day 87',
#  't2m at day 88',
#  't2m at day 89',
#  't2m at day 90',
#  't2m at day 91',
#  't2m at day 92',
#  't2m at day 93',
#  't2m at day 94',
#  't2m at day 95',
#  't2m at day 96',
#  't2m at day 97',
#  't2m at day 98',
#  't2m at day 99',
#  't2m at day 100',
#  't2m at day 101',
#  't2m at day 102',
#  't2m at day 103',
#  't2m at day 104',
#  't2m at day 105',
#  't2m at day 106',
#  't2m at day 107',
#  't2m at day 108',
#  't2m at day 109',
#  't2m at day 110',
#  't2m at day 111',
#  't2m at day 112',
#  't2m at day 113',
#  't2m at day 114',
#  't2m at day 115',
#  't2m at day 116',
#  't2m at day 117',
#  't2m at day 118',
#  't2m at day 119',
#  't2m at day 120',
#  't2m at day 121',
#  't2m at day 122',
#  't2m at day 123',
#  't2m at day 124',
#  't2m at day 125',
#  't2m at day 126',
#  't2m at day 127',
#  't2m at day 128',
#  't2m at day 129',
#  't2m at day 130',
#  't2m at day 131',
#  't2m at day 132',
#  't2m at day 133',
#  't2m at day 134',
#  't2m at day 135',
#  't2m at day 136',
#  't2m at day 137',
#  't2m at day 138',
#  't2m at day 139',
#  't2m at day 140',
#  't2m at day 141',
#  't2m at day 142',
#  't2m at day 143',
#  't2m at day 144',
#  't2m at day 145',
#  't2m at day 146',
#  't2m at day 147',
#  't2m at day 148',
#  't2m at day 149',
#  't2m at day 150',
#  't2m at day 151',
#  't2m at day 152',
#  't2m at day 153',
#  't2m at day 154',
#  't2m at day 155',
#  't2m at day 156',
#  't2m at day 157',
#  't2m at day 158',
#  't2m at day 159',
#  't2m at day 160',
#  't2m at day 161',
#  't2m at day 162',
#  't2m at day 163',
#  't2m at day 164',
#  't2m at day 165',
#  't2m at day 166',
#  't2m at day 167',
#  't2m at day 168',
#  't2m at day 169',
#  't2m at day 170',
#  't2m at day 171',
#  't2m at day 172',
#  't2m at day 173',
#  't2m at day 174',
#  't2m at day 175',
#  't2m at day 176',
#  't2m at day 177',
#  't2m at day 178',
#  't2m at day 179',
#  't2m at day 180',
#  't2m at day 181',
#  't2m at day 182',
#  't2m at day 183',
#  't2m at day 184',
#  't2m at day 185',
#  't2m at day 186',
#  't2m at day 187',
#  't2m at day 188',
#  't2m at day 189',
#  't2m at day 190',
#  't2m at day 191',
#  't2m at day 192',
#  't2m at day 193',
#  't2m at day 194',
#  't2m at day 195',
#  't2m at day 196',
#  't2m at day 197',
#  't2m at day 198',
#  't2m at day 199',
#  'observed time to beginning of flowering',
#  't2min at day 0',
#  't2min at day 1',
#  't2min at day 2',
#  't2min at day 3',
#  't2min at day 4',
#  't2min at day 5',
#  't2min at day 6',
#  't2min at day 7',
#  't2min at day 8',
#  't2min at day 9',
#  't2min at day 10',
#  't2min at day 11',
#  't2min at day 12',
#  't2min at day 13',
#  't2min at day 14',
#  't2min at day 15',
#  't2min at day 16',
#  't2min at day 17',
#  't2min at day 18',
#  't2min at day 19',
#  't2min at day 20',
#  't2min at day 21',
#  't2min at day 22',
#  't2min at day 23',
#  't2min at day 24',
#  't2min at day 25',
#  't2min at day 26',
#  't2min at day 27',
#  't2min at day 28',
#  't2min at day 29',
#  't2min at day 30',
#  't2min at day 31',
#  't2min at day 32',
#  't2min at day 33',
#  't2min at day 34',
#  't2min at day 35',
#  't2min at day 36',
#  't2min at day 37',
#  't2min at day 38',
#  't2min at day 39',
#  't2min at day 40',
#  't2min at day 41',
#  't2min at day 42',
#  't2min at day 43',
#  't2min at day 44',
#  't2min at day 45',
#  't2min at day 46',
#  't2min at day 47',
#  't2min at day 48',
#  't2min at day 49',
#  't2min at day 50',
#  't2min at day 51',
#  't2min at day 52',
#  't2min at day 53',
#  't2min at day 54',
#  't2min at day 55',
#  't2min at day 56',
#  't2min at day 57',
#  't2min at day 58',
#  't2min at day 59',
#  't2min at day 60',
#  't2min at day 61',
#  't2min at day 62',
#  't2min at day 63',
#  't2min at day 64',
#  't2min at day 65',
#  't2min at day 66',
#  't2min at day 67',
#  't2min at day 68',
#  't2min at day 69',
#  't2min at day 70',
#  't2min at day 71',
#  't2min at day 72',
#  't2min at day 73',
#  't2min at day 74',
#  't2min at day 75',
#  't2min at day 76',
#  't2min at day 77',
#  't2min at day 78',
#  't2min at day 79',
#  't2min at day 80',
#  't2min at day 81',
#  't2min at day 82',
#  't2min at day 83',
#  't2min at day 84',
#  't2min at day 85',
#  't2min at day 86',
#  't2min at day 87',
#  't2min at day 88',
#  't2min at day 89',
#  't2min at day 90',
#  't2min at day 91',
#  't2min at day 92',
#  't2min at day 93',
#  't2min at day 94',
#  't2min at day 95',
#  't2min at day 96',
#  't2min at day 97',
#  't2min at day 98',
#  't2min at day 99',
#  't2min at day 100',
#  't2min at day 101',
#  't2min at day 102',
#  't2min at day 103',
#  't2min at day 104',
#  't2min at day 105',
#  't2min at day 106',
#  't2min at day 107',
#  't2min at day 108',
#  't2min at day 109',
#  't2min at day 110',
#  't2min at day 111',
#  't2min at day 112',
#  't2min at day 113',
#  't2min at day 114',
#  't2min at day 115',
#  't2min at day 116',
#  't2min at day 117',
#  't2min at day 118',
#  't2min at day 119',
#  't2min at day 120',
#  't2min at day 121',
#  't2min at day 122',
#  't2min at day 123',
#  't2min at day 124',
#  't2min at day 125',
#  't2min at day 126',
#  't2min at day 127',
#  't2min at day 128',
#  't2min at day 129',
#  't2min at day 130',
#  't2min at day 131',
#  't2min at day 132',
#  't2min at day 133',
#  't2min at day 134',
#  't2min at day 135',
#  't2min at day 136',
#  't2min at day 137',
#  't2min at day 138',
#  't2min at day 139',
#  't2min at day 140',
#  't2min at day 141',
#  't2min at day 142',
#  't2min at day 143',
#  't2min at day 144',
#  't2min at day 145',
#  't2min at day 146',
#  't2min at day 147',
#  't2min at day 148',
#  't2min at day 149',
#  't2min at day 150',
#  't2min at day 151',
#  't2min at day 152',
#  't2min at day 153',
#  't2min at day 154',
#  't2min at day 155',
#  't2min at day 156',
#  't2min at day 157',
#  't2min at day 158',
#  't2min at day 159',
#  't2min at day 160',
#  't2min at day 161',
#  't2min at day 162',
#  't2min at day 163',
#  't2min at day 164',
#  't2min at day 165',
#  't2min at day 166',
#  't2min at day 167',
#  't2min at day 168',
#  't2min at day 169',
#  't2min at day 170',
#  't2min at day 171',
#  't2min at day 172',
#  't2min at day 173',
#  't2min at day 174',
#  't2min at day 175',
#  't2min at day 176',
#  't2min at day 177',
#  't2min at day 178',
#  't2min at day 179',
#  't2min at day 180',
#  't2min at day 181',
#  't2min at day 182',
#  't2min at day 183',
#  't2min at day 184',
#  't2min at day 185',
#  't2min at day 186',
#  't2min at day 187',
#  't2min at day 188',
#  't2min at day 189',
#  't2min at day 190',
#  't2min at day 191',
#  't2min at day 192',
#  't2min at day 193',
#  't2min at day 194',
#  't2min at day 195',
#  't2min at day 196',
#  't2min at day 197',
#  't2min at day 198',
#  't2min at day 199',
#  't2max at day 0',
#  't2max at day 1',
#  't2max at day 2',
#  't2max at day 3',
#  't2max at day 4',
#  't2max at day 5',
#  't2max at day 6',
#  't2max at day 7',
#  't2max at day 8',
#  't2max at day 9',
#  't2max at day 10',
#  't2max at day 11',
#  't2max at day 12',
#  't2max at day 13',
#  't2max at day 14',
#  't2max at day 15',
#  't2max at day 16',
#  't2max at day 17',
#  't2max at day 18',
#  't2max at day 19',
#  't2max at day 20',
#  't2max at day 21',
#  't2max at day 22',
#  't2max at day 23',
#  't2max at day 24',
#  't2max at day 25',
#  't2max at day 26',
#  't2max at day 27',
#  't2max at day 28',
#  't2max at day 29',
#  't2max at day 30',
#  't2max at day 31',
#  't2max at day 32',
#  't2max at day 33',
#  't2max at day 34',
#  't2max at day 35',
#  't2max at day 36',
#  't2max at day 37',
#  't2max at day 38',
#  't2max at day 39',
#  't2max at day 40',
#  't2max at day 41',
#  't2max at day 42',
#  't2max at day 43',
#  't2max at day 44',
#  't2max at day 45',
#  't2max at day 46',
#  't2max at day 47',
#  't2max at day 48',
#  't2max at day 49',
#  't2max at day 50',
#  't2max at day 51',
#  't2max at day 52',
#  't2max at day 53',
#  't2max at day 54',
#  't2max at day 55',
#  't2max at day 56',
#  't2max at day 57',
#  't2max at day 58',
#  't2max at day 59',
#  't2max at day 60',
#  't2max at day 61',
#  't2max at day 62',
#  't2max at day 63',
#  't2max at day 64',
#  't2max at day 65',
#  't2max at day 66',
#  't2max at day 67',
#  't2max at day 68',
#  't2max at day 69',
#  't2max at day 70',
#  't2max at day 71',
#  't2max at day 72',
#  't2max at day 73',
#  't2max at day 74',
#  't2max at day 75',
#  't2max at day 76',
#  't2max at day 77',
#  't2max at day 78',
#  't2max at day 79',
#  't2max at day 80',
#  't2max at day 81',
#  't2max at day 82',
#  't2max at day 83',
#  't2max at day 84',
#  't2max at day 85',
#  't2max at day 86',
#  't2max at day 87',
#  't2max at day 88',
#  't2max at day 89',
#  't2max at day 90',
#  't2max at day 91',
#  't2max at day 92',
#  't2max at day 93',
#  't2max at day 94',
#  't2max at day 95',
#  't2max at day 96',
#  't2max at day 97',
#  't2max at day 98',
#  't2max at day 99',
#  't2max at day 100',
#  't2max at day 101',
#  't2max at day 102',
#  't2max at day 103',
#  't2max at day 104',
#  't2max at day 105',
#  't2max at day 106',
#  't2max at day 107',
#  't2max at day 108',
#  't2max at day 109',
#  't2max at day 110',
#  't2max at day 111',
#  't2max at day 112',
#  't2max at day 113',
#  't2max at day 114',
#  't2max at day 115',
#  't2max at day 116',
#  't2max at day 117',
#  't2max at day 118',
#  't2max at day 119',
#  't2max at day 120',
#  't2max at day 121',
#  't2max at day 122',
#  't2max at day 123',
#  't2max at day 124',
#  't2max at day 125',
#  't2max at day 126',
#  't2max at day 127',
#  't2max at day 128',
#  't2max at day 129',
#  't2max at day 130',
#  't2max at day 131',
#  't2max at day 132',
#  't2max at day 133',
#  't2max at day 134',
#  't2max at day 135',
#  't2max at day 136',
#  't2max at day 137',
#  't2max at day 138',
#  't2max at day 139',
#  't2max at day 140',
#  't2max at day 141',
#  't2max at day 142',
#  't2max at day 143',
#  't2max at day 144',
#  't2max at day 145',
#  't2max at day 146',
#  't2max at day 147',
#  't2max at day 148',
#  't2max at day 149',
#  't2max at day 150',
#  't2max at day 151',
#  't2max at day 152',
#  't2max at day 153',
#  't2max at day 154',
#  't2max at day 155',
#  't2max at day 156',
#  't2max at day 157',
#  't2max at day 158',
#  't2max at day 159',
#  't2max at day 160',
#  't2max at day 161',
#  't2max at day 162',
#  't2max at day 163',
#  't2max at day 164',
#  't2max at day 165',
#  't2max at day 166',
#  't2max at day 167',
#  't2max at day 168',
#  't2max at day 169',
#  't2max at day 170',
#  't2max at day 171',
#  't2max at day 172',
#  't2max at day 173',
#  't2max at day 174',
#  't2max at day 175',
#  't2max at day 176',
#  't2max at day 177',
#  't2max at day 178',
#  't2max at day 179',
#  't2max at day 180',
#  't2max at day 181',
#  't2max at day 182',
#  't2max at day 183',
#  't2max at day 184',
#  't2max at day 185',
#  't2max at day 186',
#  't2max at day 187',
#  't2max at day 188',
#  't2max at day 189',
#  't2max at day 190',
#  't2max at day 191',
#  't2max at day 192',
#  't2max at day 193',
#  't2max at day 194',
#  't2max at day 195',
#  't2max at day 196',
#  't2max at day 197',
#  't2max at day 198',
#  't2max at day 199',
#  'vpd at day 0',
#  'vpd at day 1',
#  'vpd at day 2',
#  'vpd at day 3',
#  'vpd at day 4',
#  'vpd at day 5',
#  'vpd at day 6',
#  'vpd at day 7',
#  'vpd at day 8',
#  'vpd at day 9',
#  'vpd at day 10',
#  'vpd at day 11',
#  'vpd at day 12',
#  'vpd at day 13',
#  'vpd at day 14',
#  'vpd at day 15',
#  'vpd at day 16',
#  'vpd at day 17',
#  'vpd at day 18',
#  'vpd at day 19',
#  'vpd at day 20',
#  'vpd at day 21',
#  'vpd at day 22',
#  'vpd at day 23',
#  'vpd at day 24',
#  'vpd at day 25',
#  'vpd at day 26',
#  'vpd at day 27',
#  'vpd at day 28',
#  'vpd at day 29',
#  'vpd at day 30',
#  'vpd at day 31',
#  'vpd at day 32',
#  'vpd at day 33',
#  'vpd at day 34',
#  'vpd at day 35',
#  'vpd at day 36',
#  'vpd at day 37',
#  'vpd at day 38',
#  'vpd at day 39',
#  'vpd at day 40',
#  'vpd at day 41',
#  'vpd at day 42',
#  'vpd at day 43',
#  'vpd at day 44',
#  'vpd at day 45',
#  'vpd at day 46',
#  'vpd at day 47',
#  'vpd at day 48',
#  'vpd at day 49',
#  'vpd at day 50',
#  'vpd at day 51',
#  'vpd at day 52',
#  'vpd at day 53',
#  'vpd at day 54',
#  'vpd at day 55',
#  'vpd at day 56',
#  'vpd at day 57',
#  'vpd at day 58',
#  'vpd at day 59',
#  'vpd at day 60',
#  'vpd at day 61',
#  'vpd at day 62',
#  'vpd at day 63',
#  'vpd at day 64',
#  'vpd at day 65',
#  'vpd at day 66',
#  'vpd at day 67',
#  'vpd at day 68',
#  'vpd at day 69',
#  'vpd at day 70',
#  'vpd at day 71',
#  'vpd at day 72',
#  'vpd at day 73',
#  'vpd at day 74',
#  'vpd at day 75',
#  'vpd at day 76',
#  'vpd at day 77',
#  'vpd at day 78',
#  'vpd at day 79',
#  'vpd at day 80',
#  'vpd at day 81',
#  'vpd at day 82',
#  'vpd at day 83',
#  'vpd at day 84',
#  'vpd at day 85',
#  'vpd at day 86',
#  'vpd at day 87',
#  'vpd at day 88',
#  'vpd at day 89',
#  'vpd at day 90',
#  'vpd at day 91',
#  'vpd at day 92',
#  'vpd at day 93',
#  'vpd at day 94',
#  'vpd at day 95',
#  'vpd at day 96',
#  'vpd at day 97',
#  'vpd at day 98',
#  'vpd at day 99',
#  'vpd at day 100',
#  'vpd at day 101',
#  'vpd at day 102',
#  'vpd at day 103',
#  'vpd at day 104',
#  'vpd at day 105',
#  'vpd at day 106',
#  'vpd at day 107',
#  'vpd at day 108',
#  'vpd at day 109',
#  'vpd at day 110',
#  'vpd at day 111',
#  'vpd at day 112',
#  'vpd at day 113',
#  'vpd at day 114',
#  'vpd at day 115',
#  'vpd at day 116',
#  'vpd at day 117',
#  'vpd at day 118',
#  'vpd at day 119',
#  'vpd at day 120',
#  'vpd at day 121',
#  'vpd at day 122',
#  'vpd at day 123',
#  'vpd at day 124',
#  'vpd at day 125',
#  'vpd at day 126',
#  'vpd at day 127',
#  'vpd at day 128',
#  'vpd at day 129',
#  'vpd at day 130',
#  'vpd at day 131',
#  'vpd at day 132',
#  'vpd at day 133',
#  'vpd at day 134',
#  'vpd at day 135',
#  'vpd at day 136',
#  'vpd at day 137',
#  'vpd at day 138',
#  'vpd at day 139',
#  'vpd at day 140',
#  'vpd at day 141',
#  'vpd at day 142',
#  'vpd at day 143',
#  'vpd at day 144',
#  'vpd at day 145',
#  'vpd at day 146',
#  'vpd at day 147',
#  'vpd at day 148',
#  'vpd at day 149',
#  'vpd at day 150',
#  'vpd at day 151',
#  'vpd at day 152',
#  'vpd at day 153',
#  'vpd at day 154',
#  'vpd at day 155',
#  'vpd at day 156',
#  'vpd at day 157',
#  'vpd at day 158',
#  'vpd at day 159',
#  'vpd at day 160',
#  'vpd at day 161',
#  'vpd at day 162',
#  'vpd at day 163',
#  'vpd at day 164',
#  'vpd at day 165',
#  'vpd at day 166',
#  'vpd at day 167',
#  'vpd at day 168',
#  'vpd at day 169',
#  'vpd at day 170',
#  'vpd at day 171',
#  'vpd at day 172',
#  'vpd at day 173',
#  'vpd at day 174',
#  'vpd at day 175',
#  'vpd at day 176',
#  'vpd at day 177',
#  'vpd at day 178',
#  'vpd at day 179',
#  'vpd at day 180',
#  'vpd at day 181',
#  'vpd at day 182',
#  'vpd at day 183',
#  'vpd at day 184',
#  'vpd at day 185',
#  'vpd at day 186',
#  'vpd at day 187',
#  'vpd at day 188',
#  'vpd at day 189',
#  'vpd at day 190',
#  'vpd at day 191',
#  'vpd at day 192',
#  'vpd at day 193',
#  'vpd at day 194',
#  'vpd at day 195',
#  'vpd at day 196',
#  'vpd at day 197',
#  'vpd at day 198',
#  'vpd at day 199',
#  'tp at day 0',
#  'tp at day 1',
#  'tp at day 2',
#  'tp at day 3',
#  'tp at day 4',
#  'tp at day 5',
#  'tp at day 6',
#  'tp at day 7',
#  'tp at day 8',
#  'tp at day 9',
#  'tp at day 10',
#  'tp at day 11',
#  'tp at day 12',
#  'tp at day 13',
#  'tp at day 14',
#  'tp at day 15',
#  'tp at day 16',
#  'tp at day 17',
#  'tp at day 18',
#  'tp at day 19',
#  'tp at day 20',
#  'tp at day 21',
#  'tp at day 22',
#  'tp at day 23',
#  'tp at day 24',
#  'tp at day 25',
#  'tp at day 26',
#  'tp at day 27',
#  'tp at day 28',
#  'tp at day 29',
#  'tp at day 30',
#  'tp at day 31',
#  'tp at day 32',
#  'tp at day 33',
#  'tp at day 34',
#  'tp at day 35',
#  'tp at day 36',
#  'tp at day 37',
#  'tp at day 38',
#  'tp at day 39',
#  'tp at day 40',
#  'tp at day 41',
#  'tp at day 42',
#  'tp at day 43',
#  'tp at day 44',
#  'tp at day 45',
#  'tp at day 46',
#  'tp at day 47',
#  'tp at day 48',
#  'tp at day 49',
#  'tp at day 50',
#  'tp at day 51',
#  'tp at day 52',
#  'tp at day 53',
#  'tp at day 54',
#  'tp at day 55',
#  'tp at day 56',
#  'tp at day 57',
#  'tp at day 58',
#  'tp at day 59',
#  'tp at day 60',
#  'tp at day 61',
#  'tp at day 62',
#  'tp at day 63',
#  'tp at day 64',
#  'tp at day 65',
#  'tp at day 66',
#  'tp at day 67',
#  'tp at day 68',
#  'tp at day 69',
#  'tp at day 70',
#  'tp at day 71',
#  'tp at day 72',
#  'tp at day 73',
#  'tp at day 74',
#  'tp at day 75',
#  'tp at day 76',
#  'tp at day 77',
#  'tp at day 78',
#  'tp at day 79',
#  'tp at day 80',
#  'tp at day 81',
#  'tp at day 82',
#  'tp at day 83',
#  'tp at day 84',
#  'tp at day 85',
#  'tp at day 86',
#  'tp at day 87',
#  'tp at day 88',
#  'tp at day 89',
#  'tp at day 90',
#  'tp at day 91',
#  'tp at day 92',
#  'tp at day 93',
#  'tp at day 94',
#  'tp at day 95',
#  'tp at day 96',
#  'tp at day 97',
#  'tp at day 98',
#  'tp at day 99',
#  'tp at day 100',
#  'tp at day 101',
#  'tp at day 102',
#  'tp at day 103',
#  'tp at day 104',
#  'tp at day 105',
#  'tp at day 106',
#  'tp at day 107',
#  'tp at day 108',
#  'tp at day 109',
#  'tp at day 110',
#  'tp at day 111',
#  'tp at day 112',
#  'tp at day 113',
#  'tp at day 114',
#  'tp at day 115',
#  'tp at day 116',
#  'tp at day 117',
#  'tp at day 118',
#  'tp at day 119',
#  'tp at day 120',
#  'tp at day 121',
#  'tp at day 122',
#  'tp at day 123',
#  'tp at day 124',
#  'tp at day 125',
#  'tp at day 126',
#  'tp at day 127',
#  'tp at day 128',
#  'tp at day 129',
#  'tp at day 130',
#  'tp at day 131',
#  'tp at day 132',
#  'tp at day 133',
#  'tp at day 134',
#  'tp at day 135',
#  'tp at day 136',
#  'tp at day 137',
#  'tp at day 138',
#  'tp at day 139',
#  'tp at day 140',
#  'tp at day 141',
#  'tp at day 142',
#  'tp at day 143',
#  'tp at day 144',
#  'tp at day 145',
#  'tp at day 146',
#  'tp at day 147',
#  'tp at day 148',
#  'tp at day 149',
#  'tp at day 150',
#  'tp at day 151',
#  'tp at day 152',
#  'tp at day 153',
#  'tp at day 154',
#  'tp at day 155',
#  'tp at day 156',
#  'tp at day 157',
#  'tp at day 158',
#  'tp at day 159',
#  'tp at day 160',
#  'tp at day 161',
#  'tp at day 162',
#  'tp at day 163',
#  'tp at day 164',
#  'tp at day 165',
#  'tp at day 166',
#  'tp at day 167',
#  'tp at day 168',
#  'tp at day 169',
#  'tp at day 170',
#  'tp at day 171',
#  'tp at day 172',
#  'tp at day 173',
#  'tp at day 174',
#  'tp at day 175',
#  'tp at day 176',
#  'tp at day 177',
#  'tp at day 178',
#  'tp at day 179',
#  'tp at day 180',
#  'tp at day 181',
#  'tp at day 182',
#  'tp at day 183',
#  'tp at day 184',
#  'tp at day 185',
#  'tp at day 186',
#  'tp at day 187',
#  'tp at day 188',
#  ...]

# %%
splitmin = ds_full.loc[:, ['Stations_id', 'lat', 'lon', 'Management', 'vargroup', 'Referenzjahr', 'observed time to beginning of flowering']].groupby(['lat', 'lon', 'Stations_id', 'Management', 'vargroup', 'Referenzjahr']).min()
splitmax = ds_full.loc[:, ['Stations_id', 'lat', 'lon', 'Management', 'vargroup', 'Referenzjahr', 'observed time to beginning of flowering']].groupby(['lat', 'lon', 'Stations_id', 'Management', 'vargroup', 'Referenzjahr']).max()
splitvar = ds_full.loc[:, ['Stations_id', 'lat', 'lon', 'Management', 'vargroup', 'Referenzjahr', 'observed time to beginning of flowering']].groupby(['lat', 'lon', 'Stations_id', 'Management', 'vargroup', 'Referenzjahr']).var()
sns.histplot(splitvar)#'WC SOS date',
# Out:
# <Axes: ylabel='Count'>

# %%
ds_full.to_csv(f'C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\saved_ML_datasets\\SSA_ML_ERA5_1999_2008_with_varieties2.csv')

# %%
ds_t2m_DE = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\Maize_ML_data_ERA5_t2m_pd_SOS.csv').dropna()
ds_t2m_DE['observed time to beginning of flowering'] = pd.to_timedelta(ds_t2m_DE['observed time to beginning of flowering']).dt.days#, 'D'
ds_t2m_DE = ds_t2m_DE.loc[ds_t2m_DE['observed time to beginning of flowering'] > 30] #30

# %%
ds_list = []
path_home = 'C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\Maize_ML_data_ERA5_'
path_suffix = '_pd_SOS.csv'
path_suffix = '_pd_SOS_90s.csv'
path_suffix = '_pd_SOS_2001_2024.csv'
for variable_name in ['t2m', 't2min', 't2max', 'vpd', 'tp', 'ssrd']:
    ds_DE = pd.read_csv(path_home + variable_name + path_suffix).dropna(how='all')
    ds_DE['observed time to beginning of flowering'] = pd.to_timedelta(ds_DE['observed time to beginning of flowering']).dt.days#, 'D'
    ds_DE = ds_DE.loc[ds_DE['observed time to beginning of flowering'] > 30] #30
    ds_list.append(ds_DE)

# %%
identifying_columns = ['Stations_id', 'lat', 'lon', 'Referenzjahr']
ds_full = ds_list[0]
for variable_ind, variable_name in enumerate(['t2min', 't2max', 'vpd', 'tp', 'ssrd']):
    ds_full = ds_full.merge(ds_list[variable_ind + 1][identifying_columns + [f'{variable_name} at day {n}' for n in range (180)]], on = identifying_columns)

# %%
def get_categories(anthesis_date):
    return np.array([anthesis_date < n for n in range(183)]).squeeze().astype(np.int64)
cats = ds_full[['observed time to beginning of flowering']].apply(get_categories, args = (), axis = 1)
cats_unlisted = cats.apply(lambda x: pd.Series(x)) #to_frame().T#.explode()#.T.explode()
cats_unlisted = cats_unlisted.rename(columns = {n: f'dev stage at day {n}' for n in range(183)})
ds_full = ds_full.merge(cats_unlisted, left_index=True, right_index = True)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
ds_full.loc[:, [f'DTF at day {n}' for n in range(193)]] = np.tile(ds_full['observed time to beginning of flowering'].values, (193, 1)).T - np.tile(np.arange(0, 193), (len(ds_full),1))
ds_full.loc[:, [f'dev stage at day {n}' for n in range(193)]] =(ds_full.loc[:, [f'DTF at day {n}' for n in range(193)]] <= 0).astype(int).values
#np.any((ds_full.loc[:, [f'dev stage at day {n}' for n in range(193)]].values*ds_full.loc[:, [f'DTF at day {n}' for n in range(193)]].values) >0)

# %%
def get_photoperiods(inputs):
    #inputs = [lon, lat, day of start]
    day_of_start = datetime(inputs.iloc[2].year, inputs.iloc[2].month, inputs.iloc[2].day)
    lon = inputs.iloc[0]
    lat = inputs.iloc[1]
    sun = SunTimes(lon, lat) #can put altitude in also
    lengths = [(pd.to_datetime(sun.setutc(day_of_start + relativedelta(days=n))) - pd.to_datetime(sun.riseutc(day_of_start + relativedelta(days=n)))).seconds/3600 for n in range(170)]
    return np.array(lengths).squeeze().astype(np.float64)

# %%
ds_full['Planting date'] = pd.to_datetime(ds_full['Planting date'])
photoperiods = ds_full[['lon', 'lat', 'Planting date']].apply(get_photoperiods, args = (), axis = 1)
photoperiods_unlisted = photoperiods.apply(lambda x: pd.Series(x)) #to_frame().T#.explode()#.T.explode()
photoperiods_unlisted = photoperiods_unlisted.rename(columns = {n: f'photoperiod at day {n}' for n in range(170)})
ds_full = ds_full.merge(photoperiods_unlisted, left_index=True, right_index = True)

# %%
ds_full.to_csv(f'C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\saved_ML_datasets\\DE_ML_ERA5_2001_2024_full.csv')

# %%
ds_full = pd.read_csv(f'C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\saved_ML_datasets\\DE_ML_ERA5_90s.csv')
ds2 = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\saved_ML_datasets\\DE_ML_ERA5_2001_2024.csv')
ds_mega = pd.concat([ds_full, ds2], ignore_index=True, sort=False)
ds_varieties = ds_mega.loc[ds_mega['SORTE'] != ' Mais, Sorte unbekannt'].dropna(subset = ['SORTE'])

# %%
ds_mega.loc[ds_mega['SORTE'].isin([' Mais, frühe Reife, FAO 220',
       ' Mais, frühe Reife, FAO 210', ' Mais, mittelfrühe Reife, FAO 240',
       ' Mais, mittelfrühe Reife, FAO 230',
       ' Mais, mittelspäte Reife, FAO 280', ' Mais, frühe Reife, FAO 200',
       ' Mais, frühe Reife, FAO 190',
       ' Mais, mittelfrühe Reife, FAO 250', ' Mais, frühe Reife, FAO 180',
       ' Mais, mittelspäte Reife, FAO 260', ' Mais, späte Reife, FAO 350',
       ' Mais, mittelspäte Reife, FAO 270',
       ' Mais, mittelspäte Reife, FAO 290', ' Mais, späte Reife, FAO 300',
       ' Mais, späte Reife, FAO 310', ' Mais, frühe Reife, FAO 170',
       ' Mais, späte Reife, FAO 320', 
       ' Mais, späte Reife, FAO 330',])]# ==' Mais, frühe Reife, FAO 220']
# Out:
#        Unnamed: 0.1  Unnamed: 0 Planting date  Referenzjahr  Stations_id  \
# 1                 1          10    1991-04-25          1991         7516
# 2                 2          11    1992-04-24          1992         7516
# 3                 3          12    1993-04-24          1993         7516
# 4                 4          13    1994-04-28          1994         7516
# 5                 5          14    1995-05-02          1995         7516
# ...             ...         ...           ...           ...          ...
# 26127         15222       84498    2001-05-06          2001        19734
# 26128         15223       84499    2002-04-26          2002        19734
# 26155         15250       84600    2001-04-20          2001        19740
# 26164         15259       84686    2001-05-03          2001        19741
# 26165         15260       84687    2002-05-05          2002        19741
#
#            lat      lon  Objekt_id Reporting method Historic or recent  ...  \
# 1      54.4000   9.9667        215           annual           historic  ...
# 2      54.4000   9.9667        215           annual           historic  ...
# 3      54.4000   9.9667        215           annual           historic  ...
# 4      54.4000   9.9667        215           annual           historic  ...
# 5      54.4000   9.9667        215           annual           historic  ...
# ...        ...      ...        ...              ...                ...  ...
# 26127  51.5448  10.8748        215           annual           historic  ...
# 26128  51.5448  10.8748        215           annual           historic  ...
# 26155  52.8719  13.3927        215           annual           historic  ...
# 26164  52.1458  11.9563        215           annual           historic  ...
# 26165  52.1458  11.9563        215           annual           historic  ...
#
#        photoperiod at day 160 photoperiod at day 161  photoperiod at day 162  \
# 1                   11.533333              11.450000               11.400000
# 2                   11.550000              11.483333               11.400000
# 3                   11.566667              11.483333               11.433333
# 4                   11.300000              11.216667               11.166667
# 5                   11.016667              10.950000               10.900000
# ...                       ...                    ...                     ...
# 26127               10.850000              10.783333               10.716667
# 26128               11.516667              11.450000               11.366667
# 26155               11.883333              11.800000               11.733333
# 26164               11.016667              10.950000               10.883333
# 26165               10.900000              10.850000               10.766667
#
#       photoperiod at day 163  photoperiod at day 164  photoperiod at day 165  \
# 1                  11.316667               11.250000               11.166667
# 2                  11.333333               11.250000               11.183333
# 3                  11.350000               11.283333               11.200000
# 4                  11.083333               11.016667               10.933333
# 5                  10.816667               10.750000               10.666667
# ...                      ...                     ...                     ...
# 26127              10.650000               10.583333               10.516667
# 26128              11.316667               11.250000               11.183333
# 26155              11.683333               11.600000               11.533333
# 26164              10.816667               10.750000               10.700000
# 26165              10.700000               10.633333               10.583333
#
#        photoperiod at day 166  photoperiod at day 167  photoperiod at day 168  \
# 1                   11.100000               11.016667               10.950000
# 2                   11.116667               11.050000               10.966667
# 3                   11.133333               11.066667               10.983333
# 4                   10.866667               10.783333               10.716667
# 5                   10.600000               10.533333               10.450000
# ...                       ...                     ...                     ...
# 26127               10.450000               10.400000               10.333333
# 26128               11.116667               11.050000               10.983333
# 26155               11.450000               11.400000               11.333333
# 26164               10.616667               10.550000               10.483333
# 26165               10.516667               10.433333               10.366667
#
#        photoperiod at day 169
# 1                   10.866667
# 2                   10.900000
# 3                   10.916667
# 4                   10.650000
# 5                   10.383333
# ...                       ...
# 26127               10.266667
# 26128               10.933333
# 26155               11.250000
# 26164               10.433333
# 26165               10.300000
#
# [10183 rows x 2424 columns]
