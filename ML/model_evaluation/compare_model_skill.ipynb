# %%
import numpy as np
import pandas as pd
import xarray as xr

import skill_metrics as sm
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns
from scipy.interpolate import griddata
from scipy.ndimage import gaussian_filter
import plotting
import geopandas as gpd
import geoplot
import cartopy.io.shapereader as shpreader
import shapely
import rioxarray
from statsmodels.nonparametric.kernel_regression import KernelReg
import modelling_fctns

# %%
year = 2023
dates = xr.date_range(start=f'{year-1}-10-01', end=f'{year}-10-01', calendar='standard', use_cftime=True)

# %%
dates.to_datetimeindex(time_unit='ns')
# Out:
# DatetimeIndex(['2022-10-01', '2022-10-02', '2022-10-03', '2022-10-04',
#                '2022-10-05', '2022-10-06', '2022-10-07', '2022-10-08',
#                '2022-10-09', '2022-10-10',
#                ...
#                '2023-09-22', '2023-09-23', '2023-09-24', '2023-09-25',
#                '2023-09-26', '2023-09-27', '2023-09-28', '2023-09-29',
#                '2023-09-30', '2023-10-01'],
#               dtype='datetime64[ns]', length=366, freq=None)

# %%
dates.to_datetimeindex().astype("datetime64[ns]")
# Out:
# C:\Users\wlwc1989\AppData\Local\Temp\ipykernel_32896\1596532606.py:1: FutureWarning: In a future version of xarray to_datetimeindex will default to returning a 'us'-resolution DatetimeIndex instead of a 'ns'-resolution DatetimeIndex. This warning can be silenced by explicitly passing the `time_unit` keyword argument.
#   dates.to_datetimeindex().astype("datetime64[ns]")
# DatetimeIndex(['2022-10-01', '2022-10-02', '2022-10-03', '2022-10-04',
#                '2022-10-05', '2022-10-06', '2022-10-07', '2022-10-08',
#                '2022-10-09', '2022-10-10',
#                ...
#                '2023-09-22', '2023-09-23', '2023-09-24', '2023-09-25',
#                '2023-09-26', '2023-09-27', '2023-09-28', '2023-09-29',
#                '2023-09-30', '2023-10-01'],
#               dtype='datetime64[ns]', length=366, freq=None)

# %%
def run_GDD(x, ds, driver_variable, latlon_proj = True, response_type = 'Trapezoid', 
                             phase_list = ['beginning of flowering'], exclude_unfinished = False,
                             growing_period_length = 300, thresholds = [100], 
                             title_extra='', method='scatter', savename = False, plot=False, col='blue',
                             step = 0.25):
    if response_type == 'Trapezoid':
        def response(meantemp):
            #return x[0]*modelling_fctns.Wang_Engel_Temp_response(meantemp, x[1], x[2], x[3])
            return x[0]*modelling_fctns.Trapezoid_Temp_response(meantemp, x[1], x[2], 0.2, 3)#x[3], x[4])
    elif response_type == 'Wang':
        def response(meantemp):
            #return x[0]*modelling_fctns.Wang_Engel_Temp_response(meantemp, x[1], x[2], x[3])
            return x[0]*modelling_fctns.Wang_Engel_Temp_response(meantemp, x[1], x[2], x[3])
    elif response_type == 'Convolved':
        #table = vec_expint(x[1], x[2], x[3], np.arange(0, 50, 0.5), 8, 3)#, x[4], x[5])#x[2]
        table2 = Convolved_Wang_Engel(np.arange(-10, 50, step), x[1], x[2], x[3], 3)
        table = scipy.ndimage.gaussian_filter(table2, 8/step, mode='constant', cval = 0, axes=0)
        def response(meantemp):
            return x[0]*table[(np.round(meantemp/step, decimals = 1)).astype(int) + int(10/step)]*(meantemp > -10)
    elif response_type == 'Convolved_vary_spread':
        #table = vec_expint(x[1], x[2], x[3], np.arange(0, 50, 0.5), x[4], x[5])#, x[4], x[5])#x[2]
        table2 = Convolved_Wang_Engel(np.arange(-10, 50, step), x[1], x[2], x[3], x[5])
        table = scipy.ndimage.gaussian_filter(table2, x[4]/step, mode='constant', cval = 0, axes=0)
        def response(meantemp):
            return x[0]*table[(np.round(meantemp/step, decimals = 1)).astype(int) + int(10/step)]*(meantemp > -10)
        #def response(meantemp):
        #    return x[0]*table[(np.round(meantemp/5, decimals = 1)*10).astype(int)]*(meantemp > 0)
    elif response_type == 'multi_phase':
        def response(meantemp):
            #return x[0]*modelling_fctns.Wang_Engel_Temp_response(meantemp, x[1], x[2], x[3])
            return x[0]*modelling_fctns.Wang_Engel_Temp_response(meantemp, x[1], x[2], x[3])
        responses = [lambda meantemp: x[0]*modelling_fctns.Wang_Engel_Temp_response(meantemp, x[1], x[2], x[3]),
                     lambda meantemp: x[4]*modelling_fctns.Wang_Engel_Temp_response(meantemp, x[5], x[6], x[7])]
    driver_columns = [f'{driver_variable} at day {day}' for day in range(growing_period_length)]
    ds_for_model = ds[driver_columns + ['year', 'Stations_id']].copy()
    #ds_for_model.loc[:, driver_columns] = ds_for_model.loc[:, driver_columns]#.round(decimals = 10).astype(np.float64)
    if response_type == 'multi_phase':
        t_dev = np.zeros(len(ds_for_model))
        for i, colm in enumerate(driver_columns):
            resp = modelling_fctns.phase_dependent_response2(ds_for_model.loc[:, colm], t_dev, responses, thresholds)
            #resp2 = response(ds_for_model.loc[:, colm])
            #if np.any(resp != resp2):
            #    print(resp, resp2)
            #print(resp)
            t_dev += resp
            ds_for_model.loc[:, colm] = t_dev
    else:
        ds_for_model.loc[:, driver_columns] = response(ds_for_model[driver_columns]).cumsum(axis=1)
    model_dev_time_series = ds_for_model.values.T
    column_names = np.concatenate([np.array([f'modelled time to {phase}' for phase in phase_list]), ['year'], ['Stations_id']])
    thresholds_for_phase = thresholds[-1:]
    #print(thresholds_for_phase, model_dev_time_series.shape[1])
    phase_dates_array = np.zeros((len(thresholds_for_phase), model_dev_time_series.shape[1]))#
    for obs_index in range(model_dev_time_series.shape[1]):
        #print(model_dev_time_series[:-2, obs_index])
        phase_dates_array[:, obs_index] = np.digitize(thresholds_for_phase, model_dev_time_series[:-2, obs_index].astype(np.float64))    
    #print(phase_dates_array)
    phase_dates_array = np.concatenate([phase_dates_array, [model_dev_time_series[-2]], [model_dev_time_series[-1]]], axis=0)
    phase_dates_array = pd.DataFrame(phase_dates_array.T, columns = column_names)
    comparison_array = ds.merge(phase_dates_array, how='left', on=['year', 'Stations_id']).dropna(how='all')
    #print(len(ds), len(comparison_array), len(phase_dates_array))
    if plot:
        plot_from_comparison_array(comparison_array, title_extra=title_extra, method=method, savename=savename, 
                                  phase_list=phase_list, exclude_unfinished=exclude_unfinished, growing_period_length=growing_period_length,
                                  col=col)
    return comparison_array

# %%
def run_GDD_and_get_RMSE(x, ds, driver_variable, latlon_proj = True, 
                         response_type = 'Trapezoid', phase_list = ['beginning of flowering'], 
                         new_unfinished_penalisation=False,
                         growing_period_length = 300, thresholds = [100]):
    comparison_array = run_GDD(x, ds, driver_variable, latlon_proj=latlon_proj,
                               response_type=response_type, phase_list=phase_list,
                               growing_period_length=growing_period_length, thresholds=thresholds)
    unfinished_penalty=0
    if new_unfinished_penalisation:
        unfinished_penalty = max((comparison_array[f'modelled time to {phase_list[0]}'] >growing_period_length - 3).sum() - 0.03*comparison_array.shape[0], 0)
        comparison_array = comparison_array.where(comparison_array[f'modelled time to {phase_list[0]}'] < growing_period_length).dropna()
    def RMSE(residuals):
        if len(residuals) == 0:
            return 0
        else:
            return np.sqrt(np.mean(residuals**2))
    phase = phase_list[0]
    residuals = (comparison_array[f'observed time to {phase}'] - comparison_array[f'modelled time to {phase}']).values # np.concatenate([(comparison_array[f'observed time to {phase}'].dt.days - comparison_array[f'modelled time to {phase}']).values for phase in phase_list])
    return RMSE(residuals) + unfinished_penalty#, comparison_array

# %%
df = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_TL2.csv')
df['TL method'] = 'first layer'
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_TLKG.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_TL_last.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_TL_last_conv.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_TL_first_wave.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_TL_last_wave.csv')])

# %%
df = df.loc[df['region'] == 'subhumid low']

# %%
#df_early = df.loc[df['Variety'] == 'early']
font_size = 14
fig, ax = plt.subplots()
#hue_order = ["GDD", 'WaveNet\nin domain', 'Wageningen\nmodel, TL']
ax = sns.barplot(data = df, x = 'TL method', y='R2 score', ax=ax)#, hue_order = hue_order)
#ax.set_xticks(range(4), ['Arid\nlowlands', 'Cities', 'Highlands', 'Humid\nlowlands'], fontsize =font_size - 2)
ax.set_ylabel('R2 score (pooled sample)', fontsize =font_size)
ax.set_xlabel('Fine-tuning parameters', fontsize =font_size)
ax.set_title('Comparison of fine-tuning parameters\non the subhumid low stations', fontsize = font_size +2)
ax.set_ylim((-0.01, 0.4))
ax.annotate('', xy=(3, -0.45), xycoords='data',
            xytext=(3, -0.55), 
            arrowprops=dict(arrowstyle="<-", linewidth=1.5))
#sns.move_legend(
#    ax, "right",
#    bbox_to_anchor=(1.3, 0.15), title=None, frameon=True,
#)
#ax.annotate('351\ndata\npoints', xy=(-0.1, 0.6), xycoords='data')
#ax.annotate('312\ndata\npoints', xy=(0.9, 0.7), xycoords='data')
ax.tick_params(axis = 'x', rotation = 45)
ax.tick_params(labelsize = font_size - 1)
fig.tight_layout()
fig.savefig('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\plots\\for paper\\TL_comparison.png', bbox_inches = 'tight')

# %%
df = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_regions_pooled_score_indomain.csv')
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_regions_pooled_score_indomain_KG.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_regions_pooled_score_GDD.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_regions_pooled_score_Wageningen.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_regions_pooled_score_Wageningen_indomain.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_regions_pooled_score_TL.csv')])
df = df.loc[df['Model'] != 'WaveNet TL']
df.loc[df['Model'] == 'Wageningen', 'Model']= 'van Bree\nmodel, TL'
df.loc[df['Model'] == 'Wageningen in domain', 'Model']= 'van Bree\nmodel,\nin domain'
df.loc[df['Model'] == 'WaveNet in domain', 'Model']= 'WaveNet\nin domain'
df.loc[df['Model'] == 'WaveNet in domain KG', 'Model']= 'WaveNet\nin domain KG'
df.Model = pd.Categorical(df.loc[:, 'Model'], categories = ['GDD', 'WaveNet\nin domain', 'WaveNet\nin domain KG', 'van Bree\nmodel,\nin domain', 'van Bree\nmodel, TL'], ordered = True)
df = df.sort_values('Model', ascending=True)#.sort_values('region', ascending=False)#df = df.sort_values('Model', ascending=True).sort_values('region', ascending=False)#rename(index = {0:6}).set_index('Model').sort_index(ascending=True).reset_index()#sort_values('Model', ascending=True)

# %%
df.loc[df['Model'] == 'GDD']['R2 score'].mean()
# Out:
# np.float64(0.34081124376255956)

# %%
#df_early = df.loc[df['Variety'] == 'early']
font_size = 14
fig, ax = plt.subplots()
#hue_order = ["GDD", 'WaveNet\nin domain', 'Wageningen\nmodel, TL']
ax = sns.barplot(data = df, hue = 'Model', x = 'Variety', y='R2 score', ax=ax)#, hue_order = hue_order)
#ax.set_xticks(range(4), ['Arid\nlowlands', 'Cities', 'Highlands', 'Humid\nlowlands'], fontsize =font_size - 2)
ax.set_ylabel('R2 score (pooled sample)', fontsize =font_size)
ax.set_xlabel('Variety group', fontsize =font_size)
ax.set_title('Comparison of methods variety split', fontsize = font_size +2)
ax.set_ylim((-0.05, 0.9))
ax.annotate('', xy=(3, -0.45), xycoords='data',
            xytext=(3, -0.55), 
            arrowprops=dict(arrowstyle="<-", linewidth=1.5))
sns.move_legend(
    ax, "right",
    bbox_to_anchor=(1.3, 0.15), title=None, frameon=True,
)
ax.annotate('351\ndata\npoints', xy=(-0.1, 0.6), xycoords='data')
ax.annotate('312\ndata\npoints', xy=(0.9, 0.7), xycoords='data')
ax.tick_params(axis = 'x', rotation = 45)
fig.tight_layout()
fig.savefig('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\plots\\for paper\\variety_split_score.png', bbox_inches = 'tight')

# %%
df
# Out:
#    Unnamed: 0  R2 score Variety                  Model
# 0           0  0.462484   Early     WaveNet\nin domain
# 1           1  0.607779    Late     WaveNet\nin domain
# 0           0  0.395530   Early                    GDD
# 1           1  0.286092    Late                    GDD
# 0           0  0.626065   Early  Wageningen\nmodel, TL
# 1           1  0.646496    Late  Wageningen\nmodel, TL

# %%
df = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_indomain.csv')
#df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_indomain_KG.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_GDD.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_Wageningen.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_Wageningen_indomain.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_TL2.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_TREx.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_TREx_js.csv')])
df = df.loc[df['Model'] != 'WaveNet TL']
df.loc[df['Model'] == 'Wageningen', 'Model']= 'van Bree\nmodel, TL'
df.loc[df['Model'] == 'WaveNet in domain', 'Model']= 'WaveNet\nin domain'
df.loc[df['Model'] == 'Wageningen in domain', 'Model']= 'van Bree\nmodel,\nin domain'
#df.loc[df['Model'] == 'WaveNet in domain KG', 'Model']= 'WaveNet\nin domain KG'
df.Model = pd.Categorical(df.loc[:, 'Model'], categories = ['GDD', 'TREx', 'TREx just\nscale optimised', 'WaveNet\nin domain', 'van Bree\nmodel,\nin domain', 'van Bree\nmodel, TL'], ordered = True)#'WaveNet\nin domain KG', 'WaveNet TL', 
df.loc[df['region'] == 'humid high', 'region'] = 'subhumid high'
df.region = pd.Categorical(df.loc[:, 'region'], categories = ['semiarid low', 'subhumid low', 'humid low', 'arid high', 'subhumid high', 'all combined'], ordered = True)
df = df.sort_values('Model', ascending=True).sort_values('region', ascending=False)#rename(index = {0:6}).set_index('Model').sort_index(ascending=True).reset_index()#sort_values('Model', ascending=True)

# %%
#df_early = df.loc[df['Variety'] == 'early']

font_size = 14
fig, ax = plt.subplots()
#hue_order = ["GDD", 'WaveNet\nin domain', 'Wageningen\nmodel, TL']
order = ['semiarid low', 'arid high', 'humid low', 'subhumid low', 'humid high']
ax = sns.barplot(data = df, hue = 'Model', x = 'region', y='R2 score', ax=ax)#, hue_order = hue_order)
#ax.set_xticks(range(4), ['Arid\nlowlands', 'Cities', 'Highlands', 'Humid\nlowlands'], fontsize =font_size - 2)
ax.set_ylabel('R2 score (pooled sample)', fontsize =font_size)
ax.set_xlabel('Agro-ecological zone group (from FAO + grouped)', fontsize =font_size)
ax.set_title('Comparison of methods AEZ split', fontsize = font_size +2)
ax.set_ylim((-0.5, 1.1))
ax.annotate('', xy=(4, -0.45), xycoords='data',
            xytext=(4, -0.55), 
            arrowprops=dict(arrowstyle="<-", linewidth=1.5))
sns.move_legend(
    ax, "right",
    bbox_to_anchor=(1.3, 0.15), title=None, frameon=True,
)
ax.annotate('221\ndata\npoints', xy=(-0.3, 0.75), xycoords='data')
ax.annotate('135\ndata\npoints', xy=(0.7, 0.5), xycoords='data')
ax.annotate('43\ndata\npoints', xy=(1.7, 0.4), xycoords='data')
ax.annotate('109\ndata\npoints', xy=(2.7, 0.2), xycoords='data')
ax.annotate('91\ndata\npoints', xy=(3.7, 0.2), xycoords='data')
ax.tick_params(axis = 'x', rotation = 45)
fig.tight_layout()
fig.savefig('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\plots\\for paper\\region_split_score.png', bbox_inches = 'tight')

# %%
num subhumid low: 135
num semiarid low: 221 
num humid low: 43
num subhumid high: 91
num arid high: 109

# %%
#df_early = df.loc[df['Variety'] == 'early']

font_size = 14
fig, ax = plt.subplots()
#hue_order = ["GDD", 'WaveNet\nin domain', 'Wageningen\nmodel, TL']
order = ['semiarid low', 'arid high', 'humid low', 'subhumid low', 'humid high']
ax = sns.barplot(data = df, hue = 'Model', x = 'region', y='R2 score', ax=ax)#, hue_order = hue_order)
#ax.set_xticks(range(4), ['Arid\nlowlands', 'Cities', 'Highlands', 'Humid\nlowlands'], fontsize =font_size - 2)
ax.set_ylabel('R2 score (pooled sample)', fontsize =font_size)
ax.set_xlabel('Agro-ecological zone group (from FAO + grouped)', fontsize =font_size)
ax.set_title('Comparison of methods AEZ split', fontsize = font_size +2)
ax.set_ylim((-0.5, 1.1))
ax.annotate('', xy=(4, -0.45), xycoords='data',
            xytext=(4, -0.55), 
            arrowprops=dict(arrowstyle="<-", linewidth=1.5))
sns.move_legend(
    ax, "right",
    bbox_to_anchor=(1.3, 0.15), title=None, frameon=True,
)
ax.annotate('221\ndata\npoints', xy=(-0.3, 0.75), xycoords='data')
ax.annotate('135\ndata\npoints', xy=(0.7, 0.5), xycoords='data')
ax.annotate('43\ndata\npoints', xy=(1.7, 0.4), xycoords='data')
ax.annotate('109\ndata\npoints', xy=(2.7, 0.2), xycoords='data')
ax.annotate('91\ndata\npoints', xy=(3.7, 0.2), xycoords='data')
ax.tick_params(axis = 'x', rotation = 45)
fig.tight_layout()
fig.savefig('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\plots\\for paper\\region_split_score.png', bbox_inches = 'tight')

# %%
#df_early = df.loc[df['Variety'] == 'early']

font_size = 14
fig, ax = plt.subplots()
#hue_order = ["GDD", 'WaveNet\nin domain', 'Wageningen\nmodel, TL']
order = ['semiarid low', 'arid high', 'humid low', 'subhumid low', 'humid high']
ax = sns.barplot(data = df, hue = 'Model', x = 'region', y='R2 score', ax=ax)#, hue_order = hue_order)
#ax.set_xticks(range(4), ['Arid\nlowlands', 'Cities', 'Highlands', 'Humid\nlowlands'], fontsize =font_size - 2)
ax.set_ylabel('R2 score (pooled sample)', fontsize =font_size)
ax.set_xlabel('Agro-ecological zone group (from FAO + grouped)', fontsize =font_size)
ax.set_title('Comparison of methods AEZ split', fontsize = font_size +2)
ax.set_ylim((-0.5, 1.1))
ax.annotate('', xy=(3, -0.45), xycoords='data',
            xytext=(3, -0.55), 
            arrowprops=dict(arrowstyle="<-", linewidth=1.5))
sns.move_legend(
    ax, "right",
    bbox_to_anchor=(1.3, 0.15), title=None, frameon=True,
)
ax.annotate('135\ndata\npoints', xy=(-0.3, 0.5), xycoords='data')
ax.annotate('221\ndata\npoints', xy=(0.7, 0.75), xycoords='data')
ax.annotate('43\ndata\npoints', xy=(1.7, 0.4), xycoords='data')
ax.annotate('91\ndata\npoints', xy=(2.7, 0.2), xycoords='data')
ax.annotate('109\ndata\npoints', xy=(3.7, 0.2), xycoords='data')
ax.tick_params(axis = 'x', rotation = 45)
fig.tight_layout()

# %%
df_DE = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\important_results\\NEW_error_df_GDD.csv')
df_DE['model'] = 'GDD + Wang\nresponse'
df_TREx = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\important_results\\NEW_error_df_GDD_TREx.csv')
df_TREx['model'] = 'GDD + TREx\nresponse'
df_DE = pd.concat([df_DE, df_TREx])
#df_TREx = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\important_results\\NEW_error_df_TREx_opt.csv')
#df_TREx['model'] = 'GDD TREx response,\ncardinal temps & scale optimised'
#df_DE = pd.concat([df_DE, df_TREx])
df_DE = pd.concat([df_DE, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\important_results\\NEW_error_df_WaveNet.csv')])
df_DE = pd.concat([df_DE, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\important_results\\NEW_error_df_NN.csv')])
df_DE.loc[df_DE['model'] == 'accumulated NN response', 'model']= 'van Bree\nmodel'
df_DE.loc[df_DE['model'] == 'WaveNet', 'model']= 'WaveNet'
df_DE.rename(columns={'R2':'R2 score', 'model':'Model', 'region': 'Region'}, inplace=True)
df_DE.Model = pd.Categorical(df_DE.loc[:, 'Model'], categories = ['GDD + TREx\nresponse', 'GDD + Wang\nresponse', 'WaveNet', 'van Bree\nmodel'], ordered = True)#'WaveNet\nin domain KG', 'WaveNet TL',

# %%
df = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_indomain.csv')
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_GDD.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_Wageningen.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\combined_varieties_pooled_score_TREx_js.csv')])
df = df.loc[df['Model'] != 'WaveNet TL']
df.loc[df['Model'] == 'Wageningen', 'Model']= 'van Bree\nmodel'
df.loc[df['Model'] == 'WaveNet in domain', 'Model']= 'WaveNet'
df.loc[df['Model'] == 'Wageningen in domain', 'Model']= 'van Bree\nmodel,\nin domain'
df.loc[df['Model'] == 'TREx just\nscale optimised', 'Model']= 'GDD + TREx\nresponse'
df.loc[df['Model'] == 'GDD', 'Model']= 'GDD + Wang\nresponse'
#df.loc[df['Model'] == 'WaveNet in domain KG', 'Model']= 'WaveNet\nin domain KG'

df.Model = pd.Categorical(df.loc[:, 'Model'], categories = ['GDD + TREx\nresponse', 'GDD + Wang\nresponse', 'WaveNet', 'van Bree\nmodel'], ordered = True)#'WaveNet\nin domain KG', 'WaveNet TL', 
df.loc[df['region'] == 'humid high', 'region'] = 'subhumid high'
df.region = pd.Categorical(df.loc[:, 'region'], categories = ['semiarid low', 'subhumid low', 'humid low', 'arid high', 'subhumid high', 'all combined'], ordered = True)
df = df.sort_values('Model', ascending=True).sort_values('region', ascending=False)#rename(index = {0:6}).set_index('Model').sort_index(ascending=True).reset_index()#sort_values('Model', ascending=True)

#### If doing the plot for the GFEI talk ####
df = df.loc[(df['region'] == 'humid low') | (df['region'] == 'subhumid low')]
df = df.loc[df['Model'] != 'GDD + TREx\nresponse']

#### If doing the plot for the iCropM poster ####
#df = df.loc[(df['region'] == 'humid low')]
#df['region'] = 'SSA, humid lowland stations'
#df.rename(columns={'region': 'Region'}, inplace=True)

# %%
df
# Out:
#    Unnamed: 0   Variety  R2 score        region                 Model
# 3           2  combined -0.092806     humid low               WaveNet
# 3           2  combined  0.119109     humid low       van Bree\nmodel
# 3           2  combined  0.269582     humid low  GDD + Wang\nresponse
# 4           3  combined  0.289862  subhumid low               WaveNet
# 4           3  combined  0.298584  subhumid low  GDD + Wang\nresponse
# 4           3  combined  0.431420  subhumid low       van Bree\nmodel

# %%
df.Model = df.Model.str.replace('WaveNet', 'Simple machine\nlearning model').str.replace('van Bree\nmodel', 'Transfer learning\nmodel').str.replace('GDD + Wang\nresponse', 'Simple scientific\nmodel')
#### For GFEI pres do a different order ####
df.Model = pd.Categorical(df.loc[:, 'Model'], categories = ['Simple scientific\nmodel', 'Simple machine\nlearning model', 'Transfer learning\nmodel'], ordered = True)#'WaveNet\nin domain KG', 'WaveNet TL', 
df.region = df.region.str.replace('semiarid low', 'Semi-arid\nlowlands').str.replace('subhumid low', 'Subhumid\nlowlands')#.str.replace('humid low', 'Humid\nlowlands')

fig, axs = plt.subplots(figsize = (8, 9))
font_size = 22
palette = sns.color_palette("Greens_r")#palette = []
ax = axs
df_plot = df.loc[df['region'] == 'Subhumid\nlowlands']#df.loc[df['region'] == 'Semi-arid\nlowlands']
bb = sns.barplot(data = df_plot, x = 'Model', y='R2 score', 
                ax=ax, legend=False, gap = 1.5, color = palette[0])#hue='Model', palette = palette,gap 1.8
ax.set_ylim([-0.15, 0.5])
ax.tick_params(axis = 'x', rotation = 45, labelsize = font_size - 1)
ax.axhline(0, color='black', linewidth=3, alpha = 0.7)
ax.tick_params(which = 'both', labelsize = font_size - 1)#, labelleft=False, left=False)
ax.set_title('Small data (135 data points,\nsubhumid lowlands)', fontsize = font_size + 4)
ax.set_ylabel('Model skill (coefficient\nof determination)', fontsize = font_size)
ax.set_xlabel('')

fig.tight_layout(w_pad = 5)

# %%
df.Model = df.Model.str.replace('WaveNet', 'Simple machine\nlearning model').str.replace('van Bree\nmodel', 'Transfer learning\nmodel').str.replace('GDD + Wang\nresponse', 'Simple scientific\nmodel')
#### For GFEI pres do a different order ####
df.Model = pd.Categorical(df.loc[:, 'Model'], categories = ['Simple scientific\nmodel', 'Simple machine\nlearning model', 'Transfer learning\nmodel'], ordered = True)#'WaveNet\nin domain KG', 'WaveNet TL', 
df.region = df.region.str.replace('semiarid low', 'Semi-arid\nlowlands').str.replace('humid low', 'Humid\nlowlands')

fig, axs = plt.subplots(figsize = (8, 9))
font_size = 22
palette = sns.color_palette("Greens_r")#palette = []
ax = axs
df_plot = df.loc[df['region'] == 'Humid\nlowlands']
bb = sns.barplot(data = df_plot, x = 'Model', y='R2 score', 
                ax=ax, legend=False, gap = 1.5, color = palette[0])#hue='Model', palette = palette,gap 1.8
ax.set_ylim([-0.15, 0.5])
ax.tick_params(axis = 'x', rotation = 45, labelsize = font_size - 1)
ax.axhline(0, color='black', linewidth=3, alpha = 0.7)
ax.tick_params(which = 'both', labelsize = font_size - 1)#, labelleft=False, left=False)
ax.set_title('Very small data (43 data points,\nsubhumid lowlands)', fontsize = font_size + 4)
ax.set_ylabel('Model skill (coefficient\nof determination)', fontsize = font_size)
ax.set_xlabel('')

fig.tight_layout(w_pad = 5)

# %%
df
# Out:
#    Unnamed: 0   Variety  R2 score               region  \
# 3           2  combined -0.092806      Humid\nlowlands
# 3           2  combined  0.119109      Humid\nlowlands
# 3           2  combined  0.269582      Humid\nlowlands
# 1           0  combined  0.664598  Semi-arid\nlowlands
# 1           0  combined  0.659246  Semi-arid\nlowlands
# 1           0  combined  0.553431  Semi-arid\nlowlands
#
#                          Model
# 3    Simple data\ndriven model
# 3     Transfer learning\nmodel
# 3  Simple science-based\nmodel
# 1    Simple data\ndriven model
# 1     Transfer learning\nmodel
# 1  Simple science-based\nmodel

# %%
df_both = pd.concat([df[['R2 score', 'Model', 'Region']], df_DE[['R2 score', 'Model', 'Region']]])
df_both.Model = pd.Categorical(df_both.loc[:, 'Model'], categories = ['GDD + TREx response', 'GDD + Wang response', 'WaveNet', 'van Bree\nmodel'], ordered = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_both = pd.concat([df[['R2 score', 'Model', 'Region']], df_DE[['R2 score', 'Model', 'Region']]])
#       2 df_both.Model = pd.Categorical(df_both.loc[:, 'Model'], categories = ['GDD + TREx response', 'GDD + Wang response', 'WaveNet', 'van Bree\nmodel'], ordered = True)
#
# NameError: name 'df_DE' is not defined

# %%
fig, axs = plt.subplots(1, 2, figsize = (16, 9))
font_size = 22
palette = sns.color_palette("Greens_r")#palette = []
ax = axs[1]
for i, ax in enumerate(axs):
    df_plot = [df_DE[['R2 score', 'Model', 'Region']], df[['R2 score', 'Model', 'Region']]][i]
    bb = sns.barplot(data = df_plot, x = 'Model', y='R2 score', 
                    ax=ax, legend=False, gap = 1.5, color = palette[0])#hue='Model', palette = palette,gap 1.8
    hatches = ['', '..', 'xx', '//']
    #for ind, i in enumerate(bb.patches[:4]):
    #    #print(i)
    #    if ind == 1:
    #        i.set_hatch("..")
    #    elif ind == 2:
    #        i.set_hatch("xx")
    #    elif ind ==3:
    #        i.set_hatch("//")
    #    #i.set_width(0.8)
    ax.set_ylim([-0.15, 0.6])
    ax.axvline(x= 1.5, color='black', linewidth=5, linestyle = '--',alpha = 0.6)
    ax.annotate('Process-based',
            xy=(0.5, 0.55), xycoords='data',
            xytext=(0, 0), textcoords='offset pixels',
            horizontalalignment='center',
            verticalalignment='center', fontsize = font_size)
    ax.tick_params(axis = 'x', rotation = 45, labelsize = font_size - 1)
    ax.axhline(0, color='black', linewidth=3, alpha = 0.7)
    ax.set_xlabel('Model', fontsize = font_size + 2)
    ax.annotate('2\nparams\ncalibrated',
            xy=(0, 0.4), xycoords='data',
            xytext=(0, 0), textcoords='offset pixels',
            horizontalalignment='center',
            verticalalignment='center', fontsize = font_size)
    ax.annotate('4\nparams\ncalibrated',
            xy=(1, 0.4), xycoords='data',
            xytext=(0, 0), textcoords='offset pixels',
            horizontalalignment='center',
            verticalalignment='center', fontsize = font_size)
    
ax = axs[0]
ax.annotate('Machine learning\n(all trained\nin domain)',
            xy=(2.5, 0.5), xycoords='data',
            xytext=(0, 0), textcoords='offset pixels',
            horizontalalignment='center',
            verticalalignment='center', fontsize = font_size)
ax.tick_params(axis = 'y', labelsize = font_size - 1)
ax.set_title('Skill of different models in DWD data\n(data-rich, 26,000 data points)', fontsize = font_size + 4, y = 1.1)
ax.set_ylabel('Coefficient of determination (R2)', fontsize = font_size)


ax = axs[1]
ax.axvline(x= 2.5, color='black', linewidth=3, linestyle = '--', alpha = 0.6, ymax = 0.85)
ax.annotate('Transfer\nlearning',
            xy=(3, 0.35), xycoords='data',
            xytext=(0, 0), textcoords='offset pixels',
            horizontalalignment='center',
            verticalalignment='center', fontsize = font_size)
ax.annotate('Trained\nin\ndomain',
            xy=(2, 0.35), xycoords='data',
            xytext=(0, 0), textcoords='offset pixels',
            horizontalalignment='center',
            verticalalignment='center', fontsize = font_size)
ax.annotate('Machine learning',
            xy=(2.5, 0.55), xycoords='data',
            xytext=(0, 0), textcoords='offset pixels',
            horizontalalignment='center',
            verticalalignment='center', fontsize = font_size)
ax.tick_params(which = 'both', labelleft=False, left=False)
ax.set_title('Skill of different models in\nhumid lowland regions\nof CIMMYT data\n(data-scarce, 43 data points)', fontsize = font_size + 4)
ax.set_ylabel('')

fig.tight_layout(w_pad = 5)

# %%
from matplotlib.patches import Patch
fig, ax = plt.subplots(figsize = (10, 6))
palette = sns.color_palette("Greens_r")#palette = []
bb = sns.barplot(data = df_both, hue = 'Model', x = 'Region', y='R2 score', order = ['DE', 'SSA, humid lowland stations'], 
                 ax=ax, legend=False, palette = palette)#, gap = 1.8)
hatches = ['', '..', 'xx', '//']

for ind, i in enumerate(bb.patches[:8]):
    print(i)
    if ind // 2 == 1:
        i.set_hatch("..")
    elif ind // 2 == 2:
        i.set_hatch("xx")
    elif ind // 2 ==3:
       i.set_hatch("//")
    i.set_width(0.15)

legend_labels = ['GDD + TREx response', 'GDD + Wang response', 'WaveNet', 'van Bree model']

handles = [
    Patch(facecolor=palette[i], edgecolor="black", hatch=h)
    for i, h in enumerate(hatches)
]

ax.legend(
    handles,
    legend_labels,
    bbox_to_anchor=(1.05, 1),
    title="sex"
    )

#plt.show(g)
for i in bb.patches[9:]:
  print(i)
  #i.set_width(10)
  #i.set_height(10)
#bb.set_width(0.4)
# Out:
# Rectangle(xy=(-0.4, 0), width=0.2, height=0.297687, angle=0)
# Rectangle(xy=(0.6, 0), width=0.2, height=0.312843, angle=0)
# Rectangle(xy=(-0.2, 0), width=0.2, height=0.287746, angle=0)
# Rectangle(xy=(0.8, 0), width=0.2, height=0.269582, angle=0)
# Rectangle(xy=(-2.77556e-17, 0), width=0.2, height=0.389721, angle=0)
# Rectangle(xy=(1, 0), width=0.2, height=-0.092806, angle=0)
# Rectangle(xy=(0.2, 0), width=0.2, height=0.412264, angle=0)
# Rectangle(xy=(1.2, 0), width=0.2, height=0.119109, angle=0)
# C:\Users\wlwc1989\AppData\Local\Temp\ipykernel_3920\904839989.py:4: UserWarning: The palette list has more values (6) than needed (4), which may not be intended.
#   bb = sns.barplot(data = df_both, hue = 'Model', x = 'Region', y='R2 score', order = ['DE', 'SSA, humid lowland stations'],

# %%
# Out:
# [(0.8828143021914648, 0.9546943483275664, 0.8621914648212226),
#  (0.7371472510572856, 0.895517108804306, 0.7108342945021145),
#  (0.5573241061130334, 0.8164244521337947, 0.546958861976163),
#  (0.3388235294117647, 0.7117262591311034, 0.40584390618992694),
#  (0.17139561707035755, 0.581514801999231, 0.2979008073817762),
#  (0.017762399077277974, 0.44267589388696654, 0.18523644752018453)]

# %%
df = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\split_varieties_pooled_score_indomain_new_split.csv')
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\split_varieties_pooled_score_TL_new_split.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\split_varieties_pooled_score_GDD_new_split.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\TL_tests\\split_varieties_pooled_score_Wageningen_new_split.csv')])

# %%
#df = df.loc[df['Model'] != 'WaveNet TL']
df.loc[df['Model'] == 'Wageningen', 'Model']= 'Wageningen\nmodel, TL'
df.loc[df['Model'] == 'WaveNet in domain', 'Model']= 'WaveNet\nin domain'

# %%
num semiarid low: 101 
num arid high: 50 
num humid low: 17 
num subhumid low: 68 
num subhumid high: 46

# %%
df_early = df.loc[df['Variety'] == 'early']
font_size = 14
fig, ax = plt.subplots()
ax = sns.barplot(data = df_early, hue = 'Model', x = 'region', y='R2 score', ax=ax)
#ax.set_xticks(range(4), ['Arid\nlowlands', 'Cities', 'Highlands', 'Humid\nlowlands'], fontsize =font_size - 2)
ax.set_ylabel('R2 score (pooled sample)', fontsize =font_size)
ax.set_xlabel('Agro-ecological zone group (from FAO + grouped)', fontsize =font_size)
ax.set_title('Comparison of methods AEZ split, early varieties', fontsize = font_size +2)
ax.set_ylim((-0.5, 1.1))
ax.annotate('', xy=(1, -0.45), xycoords='data',
            xytext=(1, -0.55), 
            arrowprops=dict(arrowstyle="<-", linewidth=1.5))
ax.annotate('', xy=(1.75, -0.45), xycoords='data',
            xytext=(1.75, -0.55),
            arrowprops=dict(arrowstyle="<-", linewidth=1.5))
sns.move_legend(
    ax, "right",
    bbox_to_anchor=(1.3, 0.15), title=None, frameon=True,
)
ax.annotate('101\ndata\npoints', xy=(-0.3, 0.8), xycoords='data')
ax.annotate('50\ndata\npoints', xy=(0.7, 0.2), xycoords='data')
ax.annotate('17\ndata\npoints', xy=(1.7, 0.7), xycoords='data')
ax.annotate('68\ndata\npoints', xy=(2.7, 0.7), xycoords='data')
ax.annotate('46\ndata\npoints', xy=(3.7, 0.2), xycoords='data')
ax.tick_params(axis = 'x', rotation = 45)
fig.tight_layout()

# %%
df_early = df.loc[df['Variety'] == 'early']
font_size = 14
fig, ax = plt.subplots()
ax = sns.barplot(data = df_early, hue = 'Model', x = 'region', y='R2 score', ax=ax)
#ax.set_xticks(range(4), ['Arid\nlowlands', 'Cities', 'Highlands', 'Humid\nlowlands'], fontsize =font_size - 2)
ax.set_ylabel('R2 score (pooled sample)', fontsize =font_size)
ax.set_xlabel('Agro-ecological zone group (from FAO + grouped)', fontsize =font_size)
ax.set_title('Comparison of methods AEZ split, early varieties', fontsize = font_size +2)
ax.set_ylim((-0.5, 1.1))
ax.annotate('', xy=(1, -0.45), xycoords='data',
            xytext=(1, -0.55), 
            arrowprops=dict(arrowstyle="<-", linewidth=1.5))
ax.annotate('', xy=(1.75, -0.45), xycoords='data',
            xytext=(1.75, -0.55),
            arrowprops=dict(arrowstyle="<-", linewidth=1.5))
sns.move_legend(
    ax, "right",
    bbox_to_anchor=(1.3, 0.15), title=None, frameon=True,
)
ax.annotate('101\ndata\npoints', xy=(-0.3, 0.8), xycoords='data')
ax.annotate('50\ndata\npoints', xy=(0.7, 0.2), xycoords='data')
ax.annotate('17\ndata\npoints', xy=(1.7, 0.7), xycoords='data')
ax.annotate('68\ndata\npoints', xy=(2.7, 0.7), xycoords='data')
ax.annotate('46\ndata\npoints', xy=(3.7, 0.2), xycoords='data')
ax.tick_params(axis = 'x', rotation = 45)
fig.tight_layout()

# %%
num semiarid low: 120 
num arid high: 59 
num humid low: 26 
num subhumid low: 67 
num subhumid high: 45

# %%
df_late = df.loc[df['Variety'] == 'late']
font_size = 14
fig, ax = plt.subplots()
sns.barplot(data = df_late, hue = 'Model', x = 'region', y='R2 score', ax=ax)#, legend=False)
#ax.set_xticks(range(4), ['Arid\nlowlands', 'Cities', 'Highlands', 'Humid\nlowlands'], fontsize =font_size - 2)
ax.set_ylabel('R2 score (pooled sample)', fontsize =font_size)
ax.set_xlabel('Agro-ecological zone group (from FAO + grouped)', fontsize =font_size)
ax.set_title('Comparison of methods AEZ split, late varieties', fontsize = font_size +2)
ax.set_ylim((-0.5, 1.1))
ax.annotate('', xy=(2, -0.45), xycoords='data',
            xytext=(2, -0.55),
            arrowprops=dict(arrowstyle="<-", linewidth=1.5))
ax.annotate('120\ndata\npoints', xy=(-0.3, 0.8), xycoords='data')
ax.annotate('59\ndata\npoints', xy=(0.7, 0.4), xycoords='data')
ax.annotate('26\ndata\npoints', xy=(1.7, 0.2), xycoords='data')
ax.annotate('67\ndata\npoints', xy=(2.7, 0.7), xycoords='data')
ax.annotate('45\ndata\npoints', xy=(3.7, 0.2), xycoords='data')
sns.move_legend(
    ax, "right",
    bbox_to_anchor=(1.3, 0.15), title=None, frameon=True,
)
ax.tick_params(axis = 'x', rotation = 45)
fig.tight_layout()

# %%
df_late = df.loc[df['Variety'] == 'late']
font_size = 14
fig, ax = plt.subplots()
sns.barplot(data = df_late, hue = 'Model', x = 'region', y='R2 score', ax=ax)#, legend=False)
#ax.set_xticks(range(4), ['Arid\nlowlands', 'Cities', 'Highlands', 'Humid\nlowlands'], fontsize =font_size - 2)
ax.set_ylabel('R2 score (pooled sample)', fontsize =font_size)
ax.set_xlabel('Agro-ecological zone group (from FAO + grouped)', fontsize =font_size)
ax.set_title('Comparison of methods AEZ split, late varieties', fontsize = font_size +2)
ax.set_ylim((-0.5, 1.1))
ax.annotate('', xy=(2, -0.45), xycoords='data',
            xytext=(2, -0.55),
            arrowprops=dict(arrowstyle="<-", linewidth=1.5))
ax.annotate('120\ndata\npoints', xy=(-0.3, 0.8), xycoords='data')
ax.annotate('59\ndata\npoints', xy=(0.7, 0.4), xycoords='data')
ax.annotate('26\ndata\npoints', xy=(1.7, 0.2), xycoords='data')
ax.annotate('67\ndata\npoints', xy=(2.7, 0.7), xycoords='data')
ax.annotate('45\ndata\npoints', xy=(3.7, 0.2), xycoords='data')
sns.move_legend(
    ax, "right",
    bbox_to_anchor=(1.3, 0.15), title=None, frameon=True,
)
ax.tick_params(axis = 'x', rotation = 45)
fig.tight_layout()

# %%
df = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\important_results\\NEW_error_df_GDD.csv')
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\important_results\\NEW_error_df_WaveNet.csv')])
df = pd.concat([df, pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\important_results\\NEW_error_df_NN.csv')])

# %%
fig, ax = plt.subplots()
sns.barplot(df, x='model', y='R2', ax=ax)
# Out:
# <Axes: xlabel='model', ylabel='R2'>

# %%
font_size = 14
fig, ax = plt.subplots()
sns.barplot(data = df_pooled_compare, hue = 'model', x = 'region', y='R2 score', ax=ax)
ax.set_xticks(range(4), ['Arid\nlowlands', 'Cities', 'Highlands', 'Humid\nlowlands'], fontsize =font_size - 2)
ax.set_ylabel('R2 score (pooled sample)', fontsize =font_size)
ax.set_xlabel('Agro-ecological zone group (from FAO + grouped)', fontsize =font_size)
ax.set_title('Comparison of methods when split by AEZ only', fontsize = font_size +2)
ax.set_ylim((-0.1, 0.8))
fig.tight_layout()
# Out:
#    Unnamed: 0                    model region evaluation method        R2  \
# 0           0        GDD Wang response     DE    5-fold year CV  0.287746
# 0           0                  WaveNet     DE    5-fold year CV  0.389721
# 0           0  accumulated NN response     DE    5-fold year CV  0.412264
#
#    Bias (obs minus modelled)   Variance      RMSE       STD      Corr  \
# 0                  -0.427039  77.435250  8.656750  8.716122  0.640790
# 0                   0.915338  42.094478  8.077301  6.425913  0.653473
# 0                  -0.188994  43.237613  8.046789  6.501318  0.655780
#
#          Min        LQ    Median        UQ        Max
# 0 -55.666667 -5.666667 -0.666667  4.500000  51.666667
# 0 -40.000000 -3.833333  0.666667  5.333333  44.833333
# 0 -39.500000 -5.000000 -0.500000  4.166667  42.666667

# %%
import inspect 
# Get he arguments of the function
args = inspect.signature(sm.taylor_diagram).parameters

# %%
error_df_TL = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\Saved_files\\results_for_comparing\\errors_TL2.csv')

# %%
font_size = 13
fig, ax = plt.subplots()
sns.barplot(error_df_TL, x='transfer_method', y='R2', ax=ax)
ax.set_ylim((-0.1, 0.5))
ax.set_xlabel('Which parameters fine tuned', fontsize = font_size)
ax.set_ylabel('Coefficient of determination (R2)', fontsize = font_size)
ax.tick_params(which='both', labelsize = font_size)
ax.set_xticks(range(6), ['Wang-Engel\nparameters', 'First\nlayer\nin CNN','Last\nlayer\nin CNN', 'Final\nlinear\nlayer', 'First\nwave', 'Last\nwave'])
ax.set_title('Skill of transfer learning in SSA by\nwhich parameters fine tuned', fontsize = font_size + 2)
ax.annotate('', xy=(4, -0.07), xycoords='data',
            xytext=(4, -0.13), 
            arrowprops=dict(arrowstyle="<-", linewidth=1.5))
ax.annotate('', xy=(5, -0.07), xycoords='data',
            xytext=(5, -0.13),
            arrowprops=dict(arrowstyle="<-", linewidth=1.5))
fig.tight_layout()

# %%
err_df = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\important_results\\error_df.csv').drop(columns=['Unnamed: 0'])

# %%
err_df_useful = err_df.loc[((err_df['model'] == 'GDD Wang Engel')|(err_df['model'] == 'Logistic regression')|(err_df['model'] == 'random forests DTF'))&((err_df['evaluation method'] == '5-Fold')|(err_df['evaluation method'] == '5-fold'))]

# %%
err_df_useful.loc[6, 'model'] = 'Random Forests'
err_df_useful.loc[12, 'model'] = 'Random Forests'

# %%
err_df_useful
# Out:
#                   model   region evaluation method        R2  \
# 0        GDD Wang Engel  Germany            5-Fold  0.422360
# 1        GDD Wang Engel      SSA            5-Fold  0.242415
# 3   Logistic regression  Germany            5-fold  0.446303
# 4   Logistic regression      SSA            5-fold  0.405319
# 6        Random Forests      SSA            5-fold  0.354385
# 12       Random Forests  Germany            5-fold  0.424623
#
#     Bias (obs minus modelled)   Variance       RMSE       STD      Corr   Min  \
# 0                    0.196544  57.469759   8.177595  7.580095  0.652758 -45.4
# 1                   -0.133237  78.927194  10.486990  8.549305  0.549946 -21.4
# 3                    0.100999  50.377059   8.015746  7.096942  0.668896 -42.6
# 4                    0.918828  71.359880   9.228532  8.407529  0.666128 -17.0
# 6                    0.894169  83.229527   9.438324  9.048926  0.643454 -17.2
# ...

# %%
fig, ax = plt.subplots()
font_size = 12
sns.barplot(data=err_df_useful, x='model', y='R2', hue='region')
ax.tick_params(axis='both', which='major', labelsize=font_size)
ax.set_ylabel('Coefficient of\ndetermination (R2)', fontsize = font_size + 1)
ax.legend(title='Region', fontsize=font_size, title_fontsize=font_size, bbox_to_anchor=(1.05, 1), loc='upper left')
ax.set_xlabel('Model', fontsize = font_size + 1)
ax.set_title('Baseline model performance comparison\n(trained/evaluated in-domain)', fontsize = font_size + 2)
# Out:
# Text(0.5, 1.0, 'Baseline model performance comparison\n(trained/evaluated in-domain)')

# %%
err_df = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\important_results\\error_df.csv').drop(columns=['Unnamed: 0'])
err_df_useful = err_df.loc[(err_df['region'] == 'Germany')|(err_df['region'] == 'DE')|(err_df['evaluation method'] == 'Transfer DE to SSA')|(err_df['evaluation method'] == 'KG Transfer DE to SSA')]
R2s = [0.3179613947868347,0.22253692150115967,0.3240765929222107,0.16850709915161133,0.3345268964767456]
np.array(R2s).mean()
new_row = pd.DataFrame({"model": ["accumulated NN response"], "region": ["SSA"], 'evaluation method': ['fine tuning'], 'R2': np.array(R2s).mean(),
                        "Bias (obs minus modelled)": np.nan, "Variance": np.nan, "RMSE": np.nan, "STD": np.nan, "Corr": np.nan, "Min": np.nan, "LQ": np.nan, "Median": np.nan, "UQ": np.nan, "Max": np.nan})
err_df_useful = pd.concat([err_df_useful, new_row], axis=0)
err_df_useful.loc[15, 'evaluation method'] = 'fine tuning'
err_df_useful.iloc[0, 2] = '5-fold'
err_df_useful.loc[9, 'model'] = 'linear regression DTF'
err_df_useful.loc[3, 'model'] = 'logistic regression'
err_df_useful = err_df_useful.drop(21)
err_df_useful.loc[:, 'evaluation method'] = err_df_useful.loc[:, 'evaluation method'].str.replace('5-fold', 'Trained in DE,\nevaluated in DE')
err_df_useful.loc[:, 'evaluation method'] = err_df_useful.loc[:, 'evaluation method'].str.replace('Transfer DE to SSA', 'Trained in DE,\nevaluated in SSA')
err_df_useful.loc[:, 'evaluation method'] = err_df_useful.loc[:, 'evaluation method'].str.replace('fine tuning', 'Trained in DE,\nevaluated in SSA')
err_df_useful = err_df_useful.loc[err_df_useful['model'] != 'linear regression DTF']
err_df_useful = err_df_useful.rename(columns = {'evaluation method': 'Evaluation'})
err_df_useful.loc[:, 'model'] = err_df_useful.loc[:, 'model'].str.replace('GDD Wang Engel', 'GDD')
err_df_useful.loc[:, 'model'] = err_df_useful.loc[:, 'model'].str.replace('random forests DTF', 'Random\nforests')
err_df_useful.loc[:, 'model'] = err_df_useful.loc[:, 'model'].str.replace('logistic regression', 'logistic\nregression')
err_df_useful.loc[:, 'model'] = err_df_useful.loc[:, 'model'].str.replace('accumulated NN response', 'accumulated\nNN response')

# %%
#fig, ax = plt.subplots()
font_size = 13
ax = sns.barplot(data = err_df_useful, x='model', y = 'R2', hue='Evaluation', width=0.5)
ax.set_ylim((-0.2, 0.8))
ax.axhline(0, color='k', linestyle = '--')
ax.axvline(3.5, color='k', linewidth = 5)
ax.tick_params(labelrotation=40, labelsize = font_size - 1)
ax.annotate('Not fine tuned\nin SSA',
            xy=(1.5, 0.65), xycoords='data',
            xytext=(0, 0), textcoords='offset pixels',
            horizontalalignment='center',
            verticalalignment='center', fontsize = font_size)
ax.annotate('Fine tuned\nin SSA',
            xy=(4.5, 0.65), xycoords='data',
            xytext=(0, 0), textcoords='offset pixels',
            horizontalalignment='center',
            verticalalignment='center', fontsize = font_size)
ax.set_xlabel('Model', fontsize = font_size + 1)
ax.set_ylabel('Coefficient of Determination (R2)', fontsize = font_size + 1)
sns.move_legend(ax, "upper left", bbox_to_anchor = (1, 1))
ax.set_title('Transfer skill DE to SSA for\nphenology models', fontsize = font_size + 2)
ax.annotate('', xy=(0.125, -0.17), xycoords='data',
            xytext=(0.125, -0.23),
            arrowprops=dict(arrowstyle="<-"))
ax.annotate('', xy=(1.125, -0.17), xycoords='data',
            xytext=(1.125, -0.23),
            arrowprops=dict(arrowstyle="<-"))
ax.annotate('', xy=(2.125, -0.17), xycoords='data',
            xytext=(2.125, -0.23),
            arrowprops=dict(arrowstyle="<-"))
ax.annotate('', xy=(3.125, -0.17), xycoords='data',
            xytext=(3.125, -0.23),
            arrowprops=dict(arrowstyle="<-"))
# Out:
# Text(3.125, -0.23, '')

# %%
#cf_both = pd.read_csv("C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\model_output\\compare_CCNN_model_December.csv")
#cf_both = cf_both.drop(columns=['Unnamed: 0'])
#ds_inputs_DE = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\saved_ML_datasets\\DE_ML_ERA5.csv')
ds_inputs_DE = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\saved_ML_datasets\\DE_ML_ERA5_full.csv')
ds_inputs_DE=ds_inputs_DE.rename(columns={'Referenzjahr':'year'})
print(len(ds_inputs_DE))
ds_inputs_DE = ds_inputs_DE.dropna(how='all')
print(len(ds_inputs_DE))
ds_inputs_DE = ds_inputs_DE.loc[ds_inputs_DE['observed time to beginning of flowering'] < 140]
ds_inputs_DE = ds_inputs_DE.loc[ds_inputs_DE['observed time to beginning of flowering'] > 40]
print(len(ds_inputs_DE))
for vble in ['photoperiod', 'DTF', 'dev stage', 'vpd', 'ssrd', 't2max', 't2min', 'tp']:
    ds_inputs_DE = ds_inputs_DE.drop(columns = [col for col in ds_inputs_DE.columns if vble in col])
ds_inputs_DE_reduced = ds_inputs_DE.sample(frac = 0.2, random_state=1)
# Out:
# 27153
# 27153
# 27143

# %%
cf_both
# Out:
#       fitted  observed  Stations_id    year      Error      lat      lon  \
# 0       91.0      88.0       7521.0  2022.0  -5.117403  54.4333   9.8167
# 1       93.0     100.0       7521.0  2023.0   4.882597  54.4333   9.8167
# 2       83.0     101.0       7521.0  2024.0  15.882597  54.4333   9.8167
# 3       76.0      84.0       7592.0  2023.0   5.882597  53.4833  10.6333
# 4       77.0      73.0       7608.0  2024.0  -6.117403  53.5000  10.4833
# ...      ...       ...          ...     ...        ...      ...      ...
# 1443    76.0      68.0      19722.0  2023.0 -10.117403  47.8655   9.0147
# 1444    82.0      84.0      19722.0  2024.0  -0.117403  47.8655   9.0147
# 1445    76.0      67.0      19914.0  2022.0 -11.117403  50.3168   9.3627
# 1446    73.0      66.0      19914.0  2023.0  -9.117403  50.3168   9.3627
# 1447    69.0      62.0      19914.0  2024.0  -9.117403  50.3168   9.3627
#
#       modelled time to beginning of flowering  discrepancy
# ...

# %%
ds_inputs_DE['Planting date']
# Out:
# 0        2004-05-03
# 1        2005-04-25
# 2        2007-04-20
# 3        2008-04-28
# 4        2009-05-04
#             ...
# 10900    1991-04-23
# 10901    1993-04-24
# 10902    1994-04-30
# 10903    1998-05-08
# 10904    1999-04-30
# Name: Planting date, Length: 27143, dtype: object

# %%
ds_DE = pd.merge(cf_both[['Stations_id', 'year', 'fitted']], ds_inputs_DE, on = ['Stations_id', 'year'], how = 'left').drop_duplicates(subset=['Stations_id', 'year'])
cf_both = pd.read_csv("C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\model_output\\compare_CCNN_model_December.csv")#without 2 for old result
cf_both = cf_both.drop(columns=['Unnamed: 0'])
cf_both = cf_both.merge(ds_inputs_DE[['Stations_id', 'year', 'Planting date']], on=['Stations_id', 'year'], how='left')
x = [0.305, 8.1, 22.8, 38.9]
cf2 = run_GDD(x, ds_DE, 't2m', response_type='Wang', thresholds =[20], growing_period_length = 140)   #'Convolved_vary_spread''Wang'
cf_both = cf_both[['Stations_id', 'year', 'fitted', 'Planting date', 'observed']].merge(cf2[['Stations_id', 'year', 'lat', 'lon', 'modelled time to beginning of flowering', 'observed time to beginning of flowering']], on = ['Stations_id', 'year']).drop_duplicates()
for column in ['observed', 'fitted', 'modelled time to beginning of flowering']:
    cf_both.loc[:, column] = pd.to_datetime(cf_both['Planting date']).dt.dayofyear + cf_both.loc[:, column]
cf_both['discrepancy'] = cf_both['fitted'] - cf_both['modelled time to beginning of flowering']

# %%
fig, ax = plt.subplots()
sns.regplot(data=cf_both, y='observed', x='modelled time to beginning of flowering', x_bins = range(40, 150, 5), ax=ax)
ax.plot([40, 140], [40, 140], color='k', linestyle='--')

# %%
cf_both['fitted'] = cf_both['fitted'] - cf_both['fitted'].mean() + cf_both['modelled time to beginning of flowering'].mean()

# %%
len(cf_both.loc[cf_both['observed'] > 220][['lat', 'lon']].drop_duplicates())
# Out:
# 55

# %%
fig,ax = plt.subplots()
DE_adm = gpd.read_file('gadm41_DEU_1/gadm41_DEU_1.shp').dissolve()
DE_adm.explode().boundary.plot(ax=ax, zorder=1, color='black', linewidth = 0.8, alpha = 0.6)
ax.axvline(8.5, color = 'blue')
ax.axhline(53, color = 'blue')
ax.axvline(8.2, color = 'red')
ax.axhline(53.9, color = 'red')
ax.axvline(11.5, color = 'red')
ax.axvline(8, color = 'k')
ax.axhline(49, color = 'k')
ax.axhline(52, color = 'k')

# %%
##### OSTFRIESLAND #####
ostfriesland_comp = cf_both.loc[(cf_both['lat'] > 53)*(cf_both['year'] == 2022)]#]#(cf_both['lon'] < 8.5)*
of_ML_mean = (ostfriesland_comp['fitted'] - ostfriesland_comp['observed']).mean()
of_GDD_mean = (ostfriesland_comp['modelled time to beginning of flowering'] - ostfriesland_comp['observed']).mean()
of_obs_mean = ostfriesland_comp['observed'].mean()
of_ML_std = (ostfriesland_comp['fitted'] - ostfriesland_comp['observed']).std()
of_GDD_std = (ostfriesland_comp['modelled time to beginning of flowering'] - ostfriesland_comp['observed']).std()
of_obs_std = ostfriesland_comp['observed'].std()
##### Schleswig-Holstein #####
sh_comp = cf_both.loc[(cf_both['lat'] > 53)*(cf_both['year'] == 2023)]#cf_both.loc[(cf_both['lon'] > 8.2)*(cf_both['lon'] < 11.5)*(cf_both['lat'] > 53.9)]
#sh_comp = pd.concat([sh_comp, ostfriesland_comp], axis=0)
sh_ML_mean = (sh_comp['fitted'] - sh_comp['observed']).mean()
sh_GDD_mean = (sh_comp['modelled time to beginning of flowering'] - sh_comp['observed']).mean()
sh_obs_mean = sh_comp['observed'].mean()
sh_ML_std = (sh_comp['fitted'] - sh_comp['observed']).std()
sh_GDD_std = (sh_comp['modelled time to beginning of flowering'] - sh_comp['observed']).std()
sh_obs_std = sh_comp['observed'].std()
##### Rhineland #####
rhineland_comp = cf_both.loc[(cf_both['lat'] > 53)*(cf_both['year'] == 2024)]#cf_both.loc[(cf_both['lon'] < 8)*(cf_both['lat'] > 49)*(cf_both['lat'] < 52)*(cf_both['year'] == 2024)]
rhineland_ML_mean = (rhineland_comp['fitted'] - rhineland_comp['observed']).mean()
rhineland_GDD_mean = (rhineland_comp['modelled time to beginning of flowering'] - rhineland_comp['observed']).mean()
rhineland_obs_mean = rhineland_comp['observed'].mean()
rhineland_ML_std = (rhineland_comp['fitted'] - rhineland_comp['observed']).std()
rhineland_GDD_std = (rhineland_comp['modelled time to beginning of flowering'] - rhineland_comp['observed']).std()
rhineland_obs_std = rhineland_comp['observed'].std()

# %%
print(f'Ostfriesland ML mean: {of_ML_mean} +/- {of_ML_std}, GDD mean: {of_GDD_mean} +/- {of_GDD_std}, obs mean: {of_obs_mean} +/- {of_obs_std}')
print(f'Schleswig-Holstein ML mean: {sh_ML_mean} +/- {sh_ML_std}, GDD mean: {sh_GDD_mean} +/- {sh_GDD_std}, obs mean: {sh_obs_mean} +/- {sh_obs_std}')
print(f'Rhineland ML mean: {rhineland_ML_mean} +/- {rhineland_ML_std}, GDD mean: {rhineland_GDD_mean} +/- {rhineland_GDD_std}, obs mean: {rhineland_obs_mean} +/- {rhineland_obs_std}')
# Out:
# Ostfriesland ML mean: -2.838235294117647 +/- 7.456561358098916, GDD mean: 0.5 +/- 7.302626801977164, obs mean: 207.38235294117646 +/- 8.25350113274362
# Schleswig-Holstein ML mean: -2.6451612903225805 +/- 8.184545160346767, GDD mean: 1.6451612903225807 +/- 8.248391346779353, obs mean: 207.16129032258064 +/- 8.392411772366392
# Rhineland ML mean: -4.580645161290323 +/- 8.424298165244593, GDD mean: -1.5 +/- 8.318949334668824, obs mean: 207.20967741935485 +/- 9.319707827641194

# %%
cf_both.loc[cf_both['lon'] < 8]
# Out:
#       Stations_id    year  fitted Planting date  observed      lat     lon  \
# 145        8400.0  2022.0   204.0    2022-04-27     205.0  53.1000  7.2167
# 146        8402.0  2022.0   202.0    2022-04-25     205.0  52.9667  7.7667
# 147        8402.0  2023.0   202.0    2023-04-27     205.0  52.9667  7.7667
# 148        8420.0  2023.0   199.0    2023-04-23     213.0  52.4167  7.7333
# 149        8420.0  2024.0   209.0    2024-05-12     194.0  52.4167  7.7333
# ...           ...     ...     ...           ...       ...      ...     ...
# 1407      19477.0  2024.0   200.0    2024-04-14     228.0  50.7983  6.0244
# 1413      19483.0  2022.0   205.0    2022-04-28     204.0  50.3602  6.8697
# 1414      19483.0  2023.0   221.0    2023-05-21     218.0  50.3602  6.8697
# 1415      19483.0  2024.0   220.0    2024-05-15     226.0  50.3602  6.8697
# 1442      19702.0  2022.0   180.0    2022-03-30     185.0  48.0908  7.6353
#
#       modelled time to beginning of flowering  \
# ...

# %%
pd

# %%
import copy
n_cells = 30 #number of cells to evaluate smooth
bandwidth = 0.7 #bandwidth for kernel smooth in degrees. 0.7 seems to work best
figsize = 10
label_size = 13
DE_adm = gpd.read_file('gadm41_DEU_1/gadm41_DEU_1.shp').dissolve()
#fig, axs = plt.subplots(3, 3, figsize=(15, 15))
fig = plt.figure()
fig.set_figheight(figsize)#15
fig.set_figwidth(figsize*(10/9)*(4/5))#22
axs = []
axs.append(plt.subplot2grid(shape=(9, 10), loc=(0, 0), colspan=3, rowspan = 3))
axs.append(plt.subplot2grid(shape=(9, 10), loc=(3, 0), colspan=3, rowspan = 3))
axs.append(plt.subplot2grid(shape=(9, 10), loc=(6, 0), colspan=3, rowspan = 3))
axs.append(plt.subplot2grid(shape=(9, 10), loc=(0, 3), colspan=3, rowspan = 3))
axs.append(plt.subplot2grid(shape=(9, 10), loc=(3, 3), colspan=3, rowspan = 3))
axs.append(plt.subplot2grid(shape=(9, 10), loc=(6, 3), colspan=3, rowspan = 3))
axs.append(plt.subplot2grid(shape=(9, 10), loc=(0, 6), colspan=3, rowspan = 3))
axs.append(plt.subplot2grid(shape=(9, 10), loc=(3, 6), colspan=3, rowspan = 3))
axs.append(plt.subplot2grid(shape=(9, 10), loc=(6, 6), colspan=3, rowspan = 3))
#axs.append(plt.subplot2grid(shape=(9, 10), loc=(0, 9), colspan=1, rowspan = 3))
axs.append(plt.subplot2grid(shape=(9, 10), loc=(3, 9), colspan=1, rowspan = 3))
#axs.append(plt.subplot2grid(shape=(9, 10), loc=(6, 9), colspan=1, rowspan = 3))
for i_year, year in enumerate([2022, 2023, 2024]):
    cf_both_year = cf_both.loc[cf_both['year'] == year]
    x = cf_both_year['lon'].values
    y = cf_both_year['lat'].values
    z = cf_both_year['observed'].values
    # make regular grid
    xi = np.linspace(x.min(), x.max(), n_cells)
    yi = np.linspace(y.min(), y.max(), n_cells)
    xi, yi = np.meshgrid(xi, yi)
    xy = gpd.GeoDataFrame({'geometry': gpd.points_from_xy(xi.flatten(), yi.flatten()), 'ref_index': np.array(range(len(yi.flatten())))}, crs='EPSG:4326')
    intersection = gpd.overlay(DE_adm, xy, keep_geom_type=False)
    # Kernel regression on irregular 2D data
    vmax = cf_both_year['observed'].quantile(0.9)
    vmin = cf_both_year['observed'].quantile(0.1)
    for i_model, obs_or_model in enumerate(['observed', 'fitted', 'modelled time to beginning of flowering']):
        title = ['observed', 'WaveNet', 'GDD + Wang'][i_model]
        axis_index = (i_model * 3) + i_year
        ax = axs[axis_index]
        #cf_both_year.loc[:, obs_or_model] = cf_both_year[obs_or_model] - cf_both_year[obs_or_model].mean()
        kr = KernelReg(endog=cf_both_year[obs_or_model].values, exog=[cf_both_year['lon'].values, cf_both_year['lat'].values], var_type='cc', bw=[bandwidth, bandwidth])
        z_smooth, _ = kr.fit([xi.flatten(),yi.flatten()])
        compliment = np.delete(np.arange(n_cells**2), intersection['ref_index'].values)
        z_smooth[compliment] = np.nan
        #z_smooth = z_smooth - z_smooth.mean()
        z_smooth = z_smooth.reshape((n_cells, n_cells))
        img = ax.pcolormesh(xi, yi, z_smooth, vmin=195, vmax = 215, cmap = 'brg')# vmin=vmin - 5, vmax = vmax + 5)#vmin = 75, vmax = 90, zorder = 0)# -7, 7 when detrending75, 90
        #geoplot.polyplot(DE_adm.explode(), ax=ax, zorder=1, alpha = 0.6)
        DE_adm.explode().boundary.plot(ax=ax, zorder=1, color='black', linewidth = 0.8, alpha = 0.6)
        if (title == 'observed') & (year == 2023):
            cbar = fig.colorbar(img, cax = axs[9])#+ i_year
            cbar.set_label('Days of flowering', fontsize = label_size - 1) #'Estimated change in\npercentage error'
            cbar.ax.tick_params(labelsize=label_size - 1)
            cbar.ax.yaxis.set_major_formatter(FuncFormatter(lambda x, pos: (pd.to_datetime(f'2000-01-01') + pd.to_timedelta(x - 1, unit='D')).strftime('%d %b')))
            ax.scatter(x, y, c='white', s=0.2*(figsize/7), zorder=2, label = 'Observation\nlocations')
        else:
            ax.scatter(x, y, c='white', zorder=2, s=0.2*(figsize/7))
        if axis_index in [5, 8]:
            ax.set_xlabel('Longitude (°)', fontsize = label_size-1)
            ax.tick_params(left = False, labelleft = False)
        elif axis_index in [0, 1]:
            ax.set_ylabel('Latitude (°)', fontsize = label_size-1)
            ax.tick_params(bottom = False, labelbottom = False)
        elif axis_index == 2:
            ax.set_xlabel('Longitude (°)', fontsize = label_size-1)
            ax.set_ylabel('Latitude (°)', fontsize = label_size-1)
        else:
            ax.tick_params(left = False, labelleft = False, bottom = False, labelbottom = False)
        ax.set_title(f'{year} - {title}', fontsize = label_size)
fig.suptitle('Spatial distribution of observed and modelled\nday of flowering in Germany', fontsize = label_size + 2)
fig.legend(bbox_to_anchor=(1.04, 0.85), facecolor='black', labelcolor='white', fontsize = label_size - 1)
fig.tight_layout()
fig.savefig('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\plots\\for paper\\kernel_smooth.png')

# %%
year_means = ds_inputs_DE[['year', 'observed time to beginning of flowering']].groupby('year').mean()

# %%
cf_both_year
# Out:
#       Stations_id    year  fitted  observed      Error      lat      lon  \
# 2          7521.0  2024.0    85.0     101.0  16.321133  54.4333   9.8167
# 4          7608.0  2024.0    79.0      73.0  -5.678867  53.5000  10.4833
# 7          7623.0  2024.0    76.0      76.0   0.321133  54.6667   9.1333
# 11         7650.0  2024.0    79.0      75.0  -3.678867  54.1000  10.8167
# 14         7662.0  2024.0    77.0      76.0  -0.678867  53.7333   9.7833
# ...           ...     ...     ...       ...        ...      ...      ...
# 1438      19612.0  2024.0    77.0      78.0   1.321133  52.0507  10.6362
# 1439      19650.0  2024.0    78.0      96.0  18.321133  51.0716   8.2904
# 1441      19700.0  2024.0    83.0      88.0   5.321133  50.4316  11.9443
# 1444      19722.0  2024.0    80.0      84.0   4.321133  47.8655   9.0147
# 1447      19914.0  2024.0    72.0      62.0  -9.678867  50.3168   9.3627
#
#       modelled time to beginning of flowering  discrepancy Planting date
# ...

# %%
label_size = 13
fig, axs = plt.subplots(3, 2, figsize=(6, 9))
for i_year, year in enumerate([2022, 2023, 2024]):
    cf_both_year = cf_both.loc[cf_both['year'] == year]
    for i_model, model in enumerate(['fitted', 'modelled time to beginning of flowering']):
        title = ['ML', 'GDD'][i_model]
        ax = axs[i_year, i_model]
        sns.regplot(data=cf_both_year, x=model, y='observed', x_bins = np.arange(70, 100, 5), ax=ax)
        ax.set_xlim((65, 105))
        ax.plot([70, 100], [70, 100], color='black', linestyle = '--', linewidth = 0.5)
        ax.set_title(f'{year} - {title}', fontsize = label_size)
        if i_model == 0 and i_year in [0, 1]:
            ax.set_ylabel('Observed time to\nbeginning of flowering (days)', fontsize = label_size - 1)
            ax.tick_params(bottom = False, labelbottom = False)
            ax.set_xlabel('')
        elif i_model == 0 and i_year == 2:
            ax.set_ylabel('Observed time to\nbeginning of flowering (days)', fontsize = label_size - 1)
            ax.set_xlabel('Predicted time to\nbeginning of flowering (days)', fontsize = label_size - 1)
        elif i_model == 1 and i_year == 2:
            ax.set_xlabel('Predicted time to\nbeginning of flowering (days)', fontsize = label_size - 1)
            ax.tick_params(left = False, labelleft = False)
            ax.set_ylabel('')
        else:
            ax.tick_params(left = False, labelleft = False, bottom = False, labelbottom = False)
            ax.set_xlabel('')
            ax.set_ylabel('')
        
fig.suptitle('Spatial distribution of observed and modelled\ntime to beginning of flowering in Germany', fontsize = label_size + 2)
#fig.legend(bbox_to_anchor=(1.06, 0.85), facecolor='black', labelcolor='white', fontsize = label_size - 1)
fig.tight_layout()

# %%
    cf_both_year = cf_both.loc[cf_both['year'] == 2024]
    # Kernel regression on irregular 2D data
    kr = KernelReg(endog=cf_both_year['observed'].values, exog=[cf_both_year['lon'].values, cf_both_year['lat'].values], var_type='cc', bw=[0.5, 0.5])
    z_smooth, _ = kr.fit([xi.flatten(),yi.flatten()])
    z_smooth = z_smooth.reshape((50, 50))

    #img = plt.imshow(z_smooth)
    fig, ax = plotting.Germany_plot()
    z_smooth2 = z_smooth#[z_smooth > 80]
    img = ax.pcolormesh(xi, yi, z_smooth2, vmin=80, vmax = 100)

    plt.colorbar(img)
    ax.scatter(x, y, c='white', s=0.5)
    #plt.colorbar(img)

# %%
cf_both['']

# %%
zi[10:30, 10:30].max()
# Out:
# np.float64(106.48375832229604)

# %%
zi_smooth
# Out:
# array([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan],
# ...

# %%
error_df = pd.read_csv('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\results_for_comparing\\important_results\\error_df.csv')
error_df.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
error_SSA = error_df.loc[error_df['region'] == 'SSA']
error_SSA= error_SSA.loc[error_SSA['evaluation method'] == '5-fold']

# %%
error_SSA = error_SSA.reset_index()#.loc[1, :]

# %%
p = np.array([1, -2*error_SSA.loc[0, 'STD']*error_SSA.loc[0, 'Corr'], error_SSA.loc[0, 'STD']**2 - error_SSA.loc[0, 'RMSE']**2])

# %%
for row in range(4):
    p = np.array([1, -2*error_SSA.loc[row, 'STD']*error_SSA.loc[row, 'Corr'], error_SSA.loc[row, 'STD']**2 - error_SSA.loc[row, 'RMSE']**2])
    print(np.roots(p)[0])
# Out:
# 12.371372218427567
# 12.677220945553804
# 12.233586386823992
# 13.6937982985195

# %%
np.roots(p)[0]
# Out:
# array([12.37137222, -1.17038381])

# %%
def taylor_stats_existing(ccoef, crmsd, sdev):
    crmsd_for_diag = [0, crmsd]
    p = np.array([1, -2*sdev*ccoef, sdev**2 - crmsd**2])
    sdev_obs = np.roots(p)[0]
    sdev_for_diag = [sdev_obs, sdev]
    ccoef_for_diag = [1, ccoef]
    return {'ccoef': ccoef_for_diag, 'crmsd': crmsd_for_diag, 'sdev': sdev_for_diag}

# %%
marker_size = 9
in_domain_symbol = '+'
transfer_symbol = '.'
MARKERS = {
        "GDD in domain": {
            "labelColor": "k",
            "symbol": in_domain_symbol,
            "size": marker_size,
            "faceColor": "w",
            "edgeColor": "r",
        },
        "GDD transfer": {
            "labelColor": "k",
            "symbol": transfer_symbol,
            "size": marker_size,
            "faceColor": "w",
            "edgeColor": "r",
        },
        "regression in domain": {
            "labelColor": "k",
            "symbol": in_domain_symbol,
            "size": marker_size,
            "faceColor": "g",
            "edgeColor": "g",
        },
        "regression transfer": {
            "labelColor": "k",
            "symbol": transfer_symbol,
            "size": marker_size,
            "faceColor": "g",
            "edgeColor": "g",
        },
        "RF in domain": {
            "labelColor": "k",
            "symbol": in_domain_symbol,
            "size": marker_size,
            "faceColor": "m",
            "edgeColor": "m",
        },
        "RF transfer": {
            "labelColor": "k",
            "symbol": transfer_symbol,
            "size": marker_size,
            "faceColor": "m",
            "edgeColor": "m",
        },
        "CCNN KG in domain": {
            "labelColor": "k",
            "symbol": in_domain_symbol,
            "size": marker_size,
            "faceColor": "c",
            "edgeColor": "c",
        },
        "CCNN FT": {
            "labelColor": "k",
            "symbol": transfer_symbol,
            "size": marker_size,
            "faceColor": "c",
            "edgeColor": "c",
        },
        "CCNN in domain": {
            "labelColor": "k",
            "symbol": in_domain_symbol,
            "size": marker_size,
            "faceColor": "k",
            "edgeColor": "k",
        },
        "CCNN transfer": {
            "labelColor": "k",
            "symbol": transfer_symbol,
            "size": marker_size,
            "faceColor": "k",
            "edgeColor": "k",
        },
        "Accumulated NN in domain": {
            "labelColor": "k",
            "symbol": in_domain_symbol,
            "size": marker_size,
            "faceColor": "b",
            "edgeColor": "b",
        },
        "Accumulated NN transfer": {
            "labelColor": "k",
            "symbol": transfer_symbol,
            "size": marker_size,
            "faceColor": "b",
            "edgeColor": "b",
            "alpha": 0,
        },
        
    }

# %%
T_stats_list = []
SSA_comp_rows = [1, 2, 5, 9, 6, 10, 16, 15, 14, 13, 20, 21]#
#SSA_comp_rows = [0, 11, 12, 17, 18, 19]
#SSA_comp_rows = [16, 15, 20, 21]
for row in SSA_comp_rows:
    T_stats = taylor_stats_existing(error_df.loc[row, 'Corr'], error_df.loc[row, 'RMSE'], error_df.loc[row, 'STD'])
    T_stats_list.append(T_stats)

# Store statistics in arrays
sdev = np.array([T_stats_list[0]['sdev'][0]] + [T_stats_list[n]['sdev'][1] for n in range(len(SSA_comp_rows))])
crmsd = np.array([T_stats_list[0]['crmsd'][0]] + [T_stats_list[n]['crmsd'][1] for n in range(len(SSA_comp_rows))])
ccoef = np.array([T_stats_list[0]['ccoef'][0]] + [T_stats_list[n]['ccoef'][1] for n in range(len(SSA_comp_rows))])

# Specify labels for points in a cell array (M1 for model prediction 1,
# etc.). Note that a label needs to be specified for the reference even
# though it is not used.
label = ['Non-Dimensional Observation'] + [error_df.loc[n, 'model'] + '\n' + error_df.loc[n, 'evaluation method'] for n in SSA_comp_rows]


#sm.taylor_diagram(sdev,crmsd,ccoef, markers = MARKERS, 
#                      markerLegend = 'on', styleOBS = '-', colOBS = 'r', markerobs = 'o',
#                      tickRMS = [0.0, 1.0, 2.0, 3.0],
#                      tickRMSangle = 115, showlabelsRMS = 'on',
#                      titleRMS = 'on', titleOBS = 'Ref')
fig, ax = plt.subplots()#figsize=(8, 8))
sm.taylor_diagram(ax, sdev,crmsd,ccoef, #markerLabel = label,
                      markers = MARKERS, markerLegend = 'on',# markerLabelColor = 'r', markercolor = ['r' for count in range(len(SSA_comp_rows))],
                      tickRMS = range(0,15,5), tickRMSangle = 110.0,
                      colRMS = 'm', styleRMS = ':', widthRMS = 2.0, 
                      titleRMS = 'on', tickSTD = range(0,15,5), 
                      axismax = 15, colSTD = 'b', styleSTD = '-.', 
                      widthSTD = 1.0, titleSTD = 'on', 
                      colCOR = 'k', styleCOR = '--', widthCOR = 1.0, 
                      titleCOR = 'on') #
fig.suptitle('Taylor Diagram for SSA models', fontsize=16)
fig.savefig('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\plots\\SSA_taylor_diag.png', bbox_inches='tight')

# %%
bxp_details = []
for row in SSA_comp_rows:
    bxp_details.append({'med': error_df.loc[row, 'Median'], 'q1': error_df.loc[row, 'LQ'], 'q3': error_df.loc[row, 'UQ'], 'whislo': error_df.loc[row, 'Min'], 'whishi': error_df.loc[row, 'Max']})
fig, ax = plt.subplots(figsize=(8, 8))
ax.bxp(bxp_details, showfliers=False)
ax.set_ylim(-10, 10)
# Out:
# (-10.0, 10.0)

# %%
sns.boxplot(error_df[['Min', 'LQ', 'Median', 'UQ', 'Max']].T)#.loc[SSA_comp_rows].plot.box()
# Out:
# <Axes: >

# %%
error_df
# Out:
#                             model   region      evaluation method         R2  \
# 0                  GDD Wang Engel  Germany                 5-Fold   0.422360
# 1                  GDD Wang Engel      SSA                 5-Fold   0.242415
# 2                  GDD Wang Engel      SSA     Transfer DE to SSA  -1.299031
# 3             Logistic regression  Germany                 5-fold   0.446303
# 4             Logistic regression      SSA                 5-fold   0.405319
# 5           linear regression DTF      SSA                 5-fold   0.373997
# 6              random forests DTF      SSA                 5-fold   0.354385
# 7   random forests classification      SSA                 5-fold   0.339676
# 8             logistic regression      SSA     Transfer DE to SSA -18.872547
# 9                  regression DTF      SSA     Transfer DE to SSA  -1.632538
# 10             random forests DTF      SSA     Transfer DE to SSA  -1.384722
# ...

# %%
sm.taylor_diagram(sdev,crmsd,ccoef, markerLabel = label,
                      markerLabelColor = 'r', markerLegend = 'on', 
                      tickRMS = range(0,60,10), 
                      colRMS = 'm', styleRMS = ':', widthRMS = 2.0, 
                      titleRMS = 'on', titleRMSDangle = 40.0, tickSTD = range(0,80,20),
                      axismax = 60.0, colSTD = 'b', styleSTD = '-.', 
                      widthSTD = 1.0, titleSTD = 'on', 
                      colCOR = 'k', styleCOR = '--', widthCOR = 1.0, 
                      titleCOR = 'on', markerSize = 10, alpha = 0.0)

# %%
error_df
# Out:
#                             model   region      evaluation method         R2  \
# 0                  GDD Wang Engel  Germany                 5-Fold   0.422360
# 1                  GDD Wang Engel      SSA                 5-Fold   0.242415
# 2                  GDD Wang Engel      SSA     Transfer DE to SSA  -1.299031
# 3             Logistic regression  Germany                 5-fold   0.446303
# 4             Logistic regression      SSA                 5-fold   0.405319
# 5           linear regression DTF      SSA                 5-fold   0.373997
# 6              random forests DTF      SSA                 5-fold   0.354385
# 7   random forests classification      SSA                 5-fold   0.339676
# 8             logistic regression      SSA     Transfer DE to SSA -18.872547
# 9                  regression DTF      SSA     Transfer DE to SSA  -1.632538
# 10             random forests DTF      SSA     Transfer DE to SSA  -1.384722
# ...

# %%
# Calculate correlation coefficient
ccoef = ccoef[0]

# Calculate centered root-mean-square (RMS) difference (E')^2
crmsd = [0.0, centered_rms_dev(p,r)]

# Calculate standard deviation of predicted field w.r.t N (sigma_p)
sdevp = np.std(p)

# Calculate standard deviation of reference field w.r.t N (sigma_r)
sdevr = np.std(r)
sdev = [sdevr, sdevp];

# Store statistics in a dictionary
stats = {'ccoef': ccoef, 'crmsd': crmsd, 'sdev': sdev}
